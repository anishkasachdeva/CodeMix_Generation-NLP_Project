# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import spacy
import random
import math
import time 
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from indicnlp.tokenize import indic_tokenize
from torchtext.legacy import data
from torchtext.legacy.data import Field, BucketIterator
device = torch.device("cuda" if torch.cuda.is_available() else 'cpu')

# %%
# !pip install indic-nlp-library
# Out:
# Requirement already satisfied: indic-nlp-library in /Users/viksitpansari/anaconda3/lib/python3.8/site-packages (0.71)
# Requirement already satisfied: numpy in /Users/viksitpansari/anaconda3/lib/python3.8/site-packages (from indic-nlp-library) (1.18.5)
# Requirement already satisfied: morfessor in /Users/viksitpansari/anaconda3/lib/python3.8/site-packages (from indic-nlp-library) (2.0.6)
# Requirement already satisfied: pandas in /Users/viksitpansari/anaconda3/lib/python3.8/site-packages (from indic-nlp-library) (1.1.2)
# Requirement already satisfied: pytz>=2017.2 in /Users/viksitpansari/anaconda3/lib/python3.8/site-packages (from pandas->indic-nlp-library) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/viksitpansari/anaconda3/lib/python3.8/site-packages (from pandas->indic-nlp-library) (2.8.1)
# Requirement already satisfied: six>=1.5 in /Users/viksitpansari/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->indic-nlp-library) (1.15.0)
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the '/Users/viksitpansari/anaconda3/bin/python3 -m pip install --upgrade pip' command.

# %%
# from indicnlp.normalize.indic_normalize import IndicNormalizerFactory

# input_text="हाँ, हाँ, बिल्कुल. मैं उसे विफल रहा है, जीवन में।\n"
# remove_nuktas=False
# factory=IndicNormalizerFactory()
# normalizer=factory.get_normalizer("hi", remove_nuktas=True)
# output_text=normalizer.normalize(input_text)

# print(input_text)
# print()
# print(output_text)

# print('Before normalization')
# print(' '.join([ hex(ord(c)) for c in input_text ] ))
# print('Length: {}'.format(len(input_text)))
# print()    
# print('After normalization')
# print(' '.join([ hex(ord(c)) for c in output_text ] ))
# print('Length: {}'.format(len(output_text))) 

# from indicnlp.tokenize import indic_tokenize  

# indic_string='सुनो, कुछ आवाज़ आ रही है। फोन?'

# print('Input String: {}'.format(indic_string))
# print('Tokens: ')
# for t in hindi_tokenizer(indic_string): 
#     print(t)

# %%
df = pd.read_csv('./train_final.txt', delimiter = "\t", header = None)
df.rename(columns = {0 : 'english', 1 : 'codemix'}, inplace = True)
en_tokenizer = spacy.load('en_core_web_sm')
df
# Out:
#                                                 english  \
# 0                                Batman2 vs2 Superman2
# 1     The2 director2 is2 Zack2 Snyder2 , 27% Rotten2...
# 2                       Not2 very2 popular2 it2 seems2
# 3     But2 the2 audiences2 liked2 it2 . It2 has2 a1 ...
# 4                                                 Yes1
# ...                                                 ...
# 8055                                             Ok1 .
# 8056                                          ok1 bro1
# 8057                            shall2 we2 continue2 ?
# 8058                           do1 you2 like2 we2 can2
# 8059                 Yeah1 I2 have2 fifteen2 thanks2 .
#
#                                                 codemix
# 0                                batman2 vs2 superman2
# 1     Zack2 Snyder2 director2 hai1 , 27% Rotten2 Tom...
# 2               lagta1 hai1 bahut1 popular1 nahi1 hai1
# 3     but2 audience2 ne2 like1 kiya1 , iska1 cinema2...
# 4                                                 yes1
# ...                                                 ...
# 8055                                        Thik1 hai1
# 8056                                  Thik1 hai1 bhai1
# 8057               Kya1 ham1 chalu1 kar1 sakte1 hai1 ?
# 8058           Kya1 aapko1 pasand1 hai1 hamare1 saath1
# 8059            Haa1 mere1 pass1 pandrah1 thanks1 hai1
#
# [8060 rows x 2 columns]

# %%
# train_temp, test_data_sent = train_test_split(df, test_size = 0.2)
# train_data_sent, validation_data_sent = train_test_split(train_temp, test_size=0.125)
# train_data_sent
# df=df.iloc[:10]
train_data_sent, test_data_sent = train_test_split(df, test_size = 0.2)
validation_data_sent = pd.read_csv('./dev_final.txt', delimiter = "\t", header = None)
validation_data_sent.rename(columns = {0 : 'english', 1 : 'codemix'}, inplace = True)
# train_data_sent
# validation_data_sent=validation_data_sent.iloc[:5]
validation_data_sent
# Out:
#                                                english  \
# 0                                              hello1
# 1    hello1 there2 , I2 have2 not2 seen2 this2 movi...
# 2    Alright2 that2 is2 fine2 . What2 is2 the2 movi...
# 3               The2 movie2 is2 The2 Social2 Network2
# 4            I2 have2 not2 seen2 that2 one2 either2 .
# ..                                                 ...
# 937                     Yep2 . Thanks2 for2 chatting2
# 938     thanks2 , I2 will2 watch2 it2 . SOunds1 good2
# 939                                             Hi1 !
# 940     Did1 you2 like2 the2 movie2 Despicable2 Me2 ?
# 941  I2 did2 not2 realize2 this2 movie2 came2 out2 ...
#
#                                                codemix
# 0                                              hello1
# 1    hello1 yar1 , mein1 is2 movie1 ko1 nahi1 dekha...
# 2       acha1 tho1 is2 movie1 kis1 baare1 me1 hein1 ?
# 3    is2 movie2 tho2 social2 network2 ke1 bare1 mei...
# 4                mein1 aise1 kuch1 nahi1 dekha1 hoon1
# ..                                                 ...
# 937             Yep2 . Thanks1 baat1 karne1 ke1 liye1
# 938   Thanks2 , mei1 dekhati1 hui1 . Achi1 baat1 hai1
# 939                                             Hi1 !
# 940  kya1 tumhe1 movie2 Despicable2 Me1 pasand1 hai...
# 941  mujhe1 nahi1 lagta1 ki1 ye1 movie2 2010 me1 aa...
#
# [942 rows x 2 columns]

# %%
train_data_sent.to_json('train_data.json', orient='records', lines=True)
validation_data_sent.to_json('validation_data.json', orient='records', lines=True)
test_data_sent.to_json('test_data.json', orient='records', lines=True)

# %%
def hindi_tokenizer(sentence):
    return [word.text for word in en_tokenizer.tokenizer(sentence.strip().split("-")[-1].strip())]    
#     return [word for word in indic_tokenize.trivial_tokenize(sentence.strip().split("-")[-1].strip())]

# %%
def english_tokenizer(sentence):
    return [word.text for word in en_tokenizer.tokenizer(sentence.strip().split("-")[-1].strip())]

# %%
HINDI = Field(tokenize = hindi_tokenizer, init_token = '<sos>', eos_token = '<eos>' , lower = True)
ENGLISH = Field(tokenize = english_tokenizer, init_token = '<sos>', eos_token = '<eos>', lower = True)
fields = {'english': ('english', ENGLISH), 'hindi': ('hindi', HINDI)}

# %%
train_data, validation_data, test_data = data.TabularDataset.splits(path = '',
                                        train = 'train_data.json',
                                        validation = 'validation_data.json',
                                        test = 'test_data.json',
                                        format = 'json',
                                        fields = fields)

print(len(train_data), len(validation_data), len(test_data))
# Out:
# 6448 942 1612

# %%
# print(train_data_sent)
print(vars(train_data.examples[0]))
# Out:
# {'english': ['on2', 'the2', 'left2', 'side2', 'there2', 'is2', 'an2', 'article2', 'and2', 'it2', 'is2', 'all2', 'about2', 'the2', 'movie2', 'home2', 'alone2', ',', 'after2', 'you2', 'read2', 'it2', 'we2', 'are2', 'supposed2', 'to2', 'discuss2', 'it2', ',', 'i2', 'think2'], 'hindi': ['left2', 'side2', 'mein1', 'kuch1', 'article2', 'hein2', ',', 'usme1', 'us1', 'movie2', 'home2', 'alone2', 'ke1', 'baare1', 'mein1', 'sab1', 'hein1', ',', 'read1', 'karne1', 'ke1', 'bad1', 'hum1', 'discuss1', 'karte1', '.']}

# %%
# for i in range(1,200,2):
#     ENGLISH.build_vocab(train_data, min_freq=i)
#     HINDI.build_vocab(train_data, min_freq=i)
#     print("\t",end=' ')
#     print(i,end=' - ')
#     print(f"English: {len(ENGLISH.vocab)}, Hindi: {len(HINDI.vocab)}")
    
ENGLISH.build_vocab(train_data, min_freq=10)
HINDI.build_vocab(train_data, min_freq=10)
print(f"English: {len(ENGLISH.vocab)}, Hindi: {len(HINDI.vocab)}")
# Out:
# English: 810, Hindi: 910

# %%
class Encoder(nn.Module):
    def __init__(self, input_size, embedding_size, hidden_size, p):
        super().__init__()
        self.dropout = nn.Dropout(p)
        self.word_embeddings = nn.Embedding(input_size, embedding_size) 
        self.gru = nn.GRU(embedding_size, hidden_size, bidirectional=True)
        self.linear = nn.Linear(2 * hidden_size, hidden_size)
        self.hidden_size = hidden_size
        
    def forward(self, input):
        embeddings = self.dropout(self.word_embeddings(input))
        o, h = self.gru(embeddings) 
        h = torch.tanh(self.linear(torch.cat((h[-2,:,:], h[-1,:,:]), dim = 1)))

        return o, h

# %%
class Decoder(nn.Module):
    def __init__(self, output_size, embedding_size, hidden_size, p, attention):
        super().__init__()
        self.dropout = nn.Dropout(p)
        self.word_embeddings = nn.Embedding(output_size, embedding_size)
        self.gru = nn.GRU(embedding_size + 2 * hidden_size, hidden_size)
        self.linear = nn.Linear(embedding_size + 3 * hidden_size, output_size)
        self.output_size = output_size
        self.attention = attention
        self.hidden_size = hidden_size

    def forward(self, input, h, eo):        
        embeddings = self.dropout(self.word_embeddings(input.unsqueeze(0)))
        alpha = self.attention(h, eo).unsqueeze(1)
        eo = eo.permute(1, 0, 2)
        w = torch.bmm(alpha, eo).permute(1, 0, 2)
        o, h = self.gru(torch.cat((embeddings, w), dim = 2), h.unsqueeze(0))
        predictions = self.linear(torch.cat((o, w, embeddings), dim = 2).squeeze(0))

        return predictions, h.squeeze(0)

# %%
class Model(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        
        self.device = device
        self.encoder = encoder
        self.decoder = decoder
         
    def forward(self, input, actual):
        
        eo, h = self.encoder(input)
        input = actual[0, :]
        predictions = torch.zeros(actual.shape[0], actual.shape[1], self.decoder.output_size).to(self.device)

        for t in range(1, actual.shape[0]):
            o, h = self.decoder(input, h, eo)
            predictions[t] = o
            predicted = o.argmax(1) 
            input = predicted

        return predictions

# %%
# a = 4
# b = a
# a = 6
# a += 1
# print(a, b)

# %%
def train(model, train_data_iterator, optimizer, criterion):
    
    model.train()    
    total_loss = 0
    
    for batch in train_data_iterator:
        input = batch.english
        actual = batch.hindi
        optimizer.zero_grad()
        predictions = model(input, actual)
        vocab_size = predictions.shape[-1]
        predictions = predictions[1:].view(-1, vocab_size)
        actual = actual[1:].view(-1) # flattening the sentence_length x batch_size dimensions because cross entropy loss needs 1d shape and also removing the sos token
        loss = criterion(predictions, actual)
        loss.backward()   
        total_loss += loss.item()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1)
        optimizer.step()
        
    average_loss = total_loss / len(train_data_iterator)
    return average_loss

# %%
def evaluate(model, data_iterator, criterion):
    
    model.eval()
    total_loss = 0
    
    with torch.no_grad():
        for batch in data_iterator:
            input = batch.english
            actual = batch.hindi
            predictions = model(input, actual)
            vocab_size = predictions.shape[-1]
            predictions = predictions[1:].view(-1, vocab_size)
            actual = actual[1:].view(-1) # flattening the sentence_length x batch_size dimensions because cross entropy loss needs 1d shape and also removing the sos token
            loss = criterion(predictions, actual)
            total_loss += loss.item()
    
    average_loss = total_loss / len(data_iterator)
    return average_loss

# %%
enc = Encoder(len(ENGLISH.vocab), 350, 512, 0.5)
attention = Attention(512)
dec = Decoder(len(HINDI.vocab), 350, 512, 0.5)

model = Model(enc, dec, device).to(device)
for name, param in model.named_parameters():
        if "weight" in name:
            nn.init.normal_(param.data, mean=0, std=0.01)
        else:
            nn.init.constant_(param.data, 0)
model
# Out:
# Model(
#   (encoder): Encoder(
#     (dropout): Dropout(p=0.5, inplace=False)
#     (word_embeddings): Embedding(3442, 350)
#     (lstm): LSTM(350, 512)
#   )
#   (decoder): Decoder(
#     (dropout): Dropout(p=0.5, inplace=False)
#     (word_embeddings): Embedding(4559, 350)
#     (lstm): LSTM(862, 512)
#     (linear): Linear(in_features=1374, out_features=4559, bias=True)
#   )
# )

# %%
optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss(ignore_index = HINDI.vocab.stoi[HINDI.pad_token])

# %%
best_loss = 1e9

train_data_iterator, validation_data_iterator, test_data_iterator = BucketIterator.splits((train_data, validation_data, test_data), batch_size = 64, device = device, sort = False)

training_losses = []
validation_losses = []

for epoch in range(25):
    train_loss = train(model, train_data_iterator, optimizer, criterion)
    valid_loss = evaluate(model, validation_data_iterator, criterion)
    training_losses.append(np.exp(train_loss))
    validation_losses.append(np.exp(valid_loss))
    if valid_loss < best_loss:
        best_loss = valid_loss
        torch.save(model.state_dict(), 'encoder_decoder.pt')
    
    print(f'Epoch: {epoch+1:02}')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
    print(f"Train Loss (exponent to analyse better): {np.exp(train_loss):.3f}")
    print(f"Val. Loss (exponent to analyse better): {np.exp(valid_loss):.3f}")
# Out:
# Epoch: 01
# 	Train Loss: 6.271 | Train PPL: 529.110
# 	 Val. Loss: 5.681 |  Val. PPL: 293.188
# Train Loss (exponent to analyse better): 529.110
# Val. Loss (exponent to analyse better): 293.188
# Epoch: 02
# 	Train Loss: 6.013 | Train PPL: 408.749
# 	 Val. Loss: 5.689 |  Val. PPL: 295.464
# Train Loss (exponent to analyse better): 408.749
# Val. Loss (exponent to analyse better): 295.464
# Epoch: 03
# 	Train Loss: 5.967 | Train PPL: 390.343
# 	 Val. Loss: 5.609 |  Val. PPL: 272.821
# Train Loss (exponent to analyse better): 390.343
# Val. Loss (exponent to analyse better): 272.821
# Epoch: 04
# 	Train Loss: 5.862 | Train PPL: 351.554
# 	 Val. Loss: 5.562 |  Val. PPL: 260.299
# Train Loss (exponent to analyse better): 351.554
# Val. Loss (exponent to analyse better): 260.299
# Epoch: 05
# 	Train Loss: 5.783 | Train PPL: 324.826
# 	 Val. Loss: 5.568 |  Val. PPL: 261.780
# Train Loss (exponent to analyse better): 324.826
# Val. Loss (exponent to analyse better): 261.780
# Epoch: 06
# 	Train Loss: 5.704 | Train PPL: 300.187
# 	 Val. Loss: 5.547 |  Val. PPL: 256.550
# Train Loss (exponent to analyse better): 300.187
# Val. Loss (exponent to analyse better): 256.550
# Epoch: 07
# 	Train Loss: 5.627 | Train PPL: 277.891
# 	 Val. Loss: 5.501 |  Val. PPL: 244.962
# Train Loss (exponent to analyse better): 277.891
# Val. Loss (exponent to analyse better): 244.962
# Epoch: 08
# 	Train Loss: 5.551 | Train PPL: 257.378
# 	 Val. Loss: 5.505 |  Val. PPL: 245.915
# Train Loss (exponent to analyse better): 257.378
# Val. Loss (exponent to analyse better): 245.915
# Epoch: 09
# 	Train Loss: 5.484 | Train PPL: 240.692
# 	 Val. Loss: 5.507 |  Val. PPL: 246.310
# Train Loss (exponent to analyse better): 240.692
# Val. Loss (exponent to analyse better): 246.310
# Epoch: 10
# 	Train Loss: 5.423 | Train PPL: 226.594
# 	 Val. Loss: 5.533 |  Val. PPL: 252.993
# Train Loss (exponent to analyse better): 226.594
# Val. Loss (exponent to analyse better): 252.993
# Epoch: 11
# 	Train Loss: 5.348 | Train PPL: 210.150
# 	 Val. Loss: 5.555 |  Val. PPL: 258.448
# Train Loss (exponent to analyse better): 210.150
# Val. Loss (exponent to analyse better): 258.448
# Epoch: 12
# 	Train Loss: 5.280 | Train PPL: 196.284
# 	 Val. Loss: 5.586 |  Val. PPL: 266.620
# Train Loss (exponent to analyse better): 196.284
# Val. Loss (exponent to analyse better): 266.620
# Epoch: 13
# 	Train Loss: 5.210 | Train PPL: 183.158
# 	 Val. Loss: 5.597 |  Val. PPL: 269.722
# Train Loss (exponent to analyse better): 183.158
# Val. Loss (exponent to analyse better): 269.722
# Epoch: 14
# 	Train Loss: 5.140 | Train PPL: 170.676
# 	 Val. Loss: 5.629 |  Val. PPL: 278.517
# Train Loss (exponent to analyse better): 170.676
# Val. Loss (exponent to analyse better): 278.517
# Epoch: 15
# 	Train Loss: 5.056 | Train PPL: 156.904
# 	 Val. Loss: 5.643 |  Val. PPL: 282.247
# Train Loss (exponent to analyse better): 156.904
# Val. Loss (exponent to analyse better): 282.247
# Epoch: 16
# 	Train Loss: 4.965 | Train PPL: 143.367
# 	 Val. Loss: 5.652 |  Val. PPL: 284.895
# Train Loss (exponent to analyse better): 143.367
# Val. Loss (exponent to analyse better): 284.895
# Epoch: 17
# 	Train Loss: 4.884 | Train PPL: 132.176
# 	 Val. Loss: 5.676 |  Val. PPL: 291.761
# Train Loss (exponent to analyse better): 132.176
# Val. Loss (exponent to analyse better): 291.761
# Epoch: 18
# 	Train Loss: 4.799 | Train PPL: 121.367
# 	 Val. Loss: 5.705 |  Val. PPL: 300.434
# Train Loss (exponent to analyse better): 121.367
# Val. Loss (exponent to analyse better): 300.434
# Epoch: 19
# 	Train Loss: 4.719 | Train PPL: 112.087
# 	 Val. Loss: 5.726 |  Val. PPL: 306.875
# Train Loss (exponent to analyse better): 112.087
# Val. Loss (exponent to analyse better): 306.875
# Epoch: 20
# 	Train Loss: 4.630 | Train PPL: 102.532
# 	 Val. Loss: 5.761 |  Val. PPL: 317.724
# Train Loss (exponent to analyse better): 102.532
# Val. Loss (exponent to analyse better): 317.724
# Epoch: 21
# 	Train Loss: 4.537 | Train PPL:  93.433
# 	 Val. Loss: 5.782 |  Val. PPL: 324.425
# Train Loss (exponent to analyse better): 93.433
# Val. Loss (exponent to analyse better): 324.425
# Epoch: 22
# 	Train Loss: 4.442 | Train PPL:  84.906
# 	 Val. Loss: 5.827 |  Val. PPL: 339.507
# Train Loss (exponent to analyse better): 84.906
# Val. Loss (exponent to analyse better): 339.507
# Epoch: 23
# 	Train Loss: 4.350 | Train PPL:  77.517
# 	 Val. Loss: 5.850 |  Val. PPL: 347.178
# Train Loss (exponent to analyse better): 77.517
# Val. Loss (exponent to analyse better): 347.178
# Epoch: 24
# 	Train Loss: 4.254 | Train PPL:  70.387
# 	 Val. Loss: 5.886 |  Val. PPL: 359.974
# Train Loss (exponent to analyse better): 70.387
# Val. Loss (exponent to analyse better): 359.974
# Epoch: 25
# 	Train Loss: 4.144 | Train PPL:  63.048
# 	 Val. Loss: 5.906 |  Val. PPL: 367.168
# Train Loss (exponent to analyse better): 63.048
# Val. Loss (exponent to analyse better): 367.168

# %%
import matplotlib.pyplot as plt

plt.plot(training_losses, label = 'Training')
plt.plot(validation_losses, label = 'Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# def get_tranlsation(text):
#   model.eval()
#   with torch.no_grad():
#     tokens = [token.text.lower() for token in en_tokenizer.tokenizer(text)][::-1]
#     tokens = [ENGLISH.init_token] + tokens + [ENGLISH.eos_token]
#     src_indexes = [ENGLISH.vocab.stoi[token] for token in tokens]
#     src_tensor = torch.LongTensor(src_indexes).unsqueeze(0).to(device)
#     src_tensor = src_tensor.reshape(-1,1)
#     output = model(src_tensor, src_tensor)
#     output_dim = output.shape[-1]
#     output = output.view(-1, output_dim)
#     indices = torch.argmax(output,dim=1).tolist()
#     return [HINDI.vocab.itos[x] for x in indices]

# print(get_tranlsation("How do you do it?"))

# %%
model.load_state_dict(torch.load('encoder_decoder.pt'))
test_loss = evaluate(model, test_data_iterator, criterion)
print(f"Test Loss (exponent to analyse better): {np.exp(test_loss):.3f}")
# Out:
# Test Loss (exponent to analyse better): 265.619

# %%
# vars(test_data.examples[2])

# %%
def translate(text):
  model.eval()
  with torch.no_grad():
    tokens = english_tokenizer(text)
    tokens = [ENGLISH.init_token] + tokens + [ENGLISH.eos_token]
    src_indexes = [ENGLISH.vocab.stoi[token] for token in tokens]
    src_tensor = torch.LongTensor(src_indexes).unsqueeze(0).to(device)
    src_tensor = src_tensor.reshape(-1,1)

    output = model(src_tensor, src_tensor)
    output_dim = output.shape[-1]
    output = output.view(-1, output_dim)
    indices = torch.argmax(output,dim=1).tolist()
    return [HINDI.vocab.itos[x] for x in indices]

print(translate("man speaking native language:"))
# Out:
# ['<unk>', 'haan1', ',', 'hai1', '<unk>', 'hai1', '<eos>']

# %%
import csv

translated_sentences = open('Paper1.csv','w')
csvwriter = csv.writer(translated_sentences)
csvwriter.writerow(['Input','Predicted','Actual'])  

for i, (eng_sentence, hin_sentence) in enumerate(zip(test_data_sent["english"], test_data_sent["hindi"])):

  hindi_predicted = translate(eng_sentence)
  hindi_predicted = " ".join(list(filter(lambda x: x != '<eos>', hindi_predicted))[1:]).strip()
  csvwriter.writerow([eng_sentence.strip(), hindi_predicted.strip(), hin_sentence.strip()])

  # print(eng_sentence.strip())
  # print(hindi_predicted)
  # print()
  # print()

translated_sentences.close()

# %%
with open('Paper1.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(f'\t{row[0]} \t \t {row[1]} \t \t {row[2]}.')
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are Input, Predicted, Actual
# 	And1 I2 am1 not2 sure2 these2 directors2 have2 done2 anything2 else2 noteworthy2 ? 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 haan1 mein1 bhi1 sure1 nahi1 is2 directors2 se2.
# 	Rotten2 Tomatoes2 is2 91%, CinemaScore2 is2 A2 +, and2 Metacritic2 Score2 is2 a2 bit2 low2 at2 73/100. 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 roten1 tomaatoz1 91% hai1 , sinemaaskor1 e1 + hai1 , aur1 metaakritik1 skor2 73/100 par1 thoda1 kam1 hai1 ..
# 	also2 stars2 Evangeline2 Lilly2 ( woman2 for2 sure2 " 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Evangeline2 Lilly2 ek1 mahila1 hai1.
# 	Well2 , thanks2 for2 sharing2 this2 conversation2 with2 me1 . It2 seems2 that2 our2 time2 has2 come2 to2 an2 end2 . I2 hope2 you2 have2 a2 wonderful2 morning2 , afternoon2 , night2 wherever2 you2 are2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 acha1 , aapse1 baath1 karne1 mein1 bahut1 dhanyavad1 . muje1 lagtha1 hein1 ki1 hamara1 time1 ab1 khatma1 ho1 raha1 hein1 , aapka1 din1 acha1 rahane1 ka1 mera1 subh1 kamna1.
# 	I2 had2 totally2 forgotten2 that2 John2 Leuizamo2 was2 in2 this2 movie2 , he2 is2 like2 the2 ninja2 actor2 that2 shows2 up2 when2 you2 least2 expect2 it2 ! 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 muje1 tho1 bilkul1 yaad1 nahi1 ki1 john2 leuizamo2 us2 movie2 mein1 hein1 , voh1 tho1 ninja2 actor2 ke1 tarah1 hein1 sabhi2 showsup1 karte1.
# 	Nice2 talking2 to2 you2 	 	 haan1 , hai1 hai1 	 	 Aap1 se1 baat1 karke1 acha1 laga1.
# 	The2 movie2 sounds2 like2 something2 I2 would2 watch2 	 	 muje1 , hai1 <unk> <unk> hai1 hai1 	 	 is2 movie1 ko1 tho1 mein1 jarur1 dekhunga1.
# 	Im2 doing2 great2 . Have2 you2 seen2 Toy2 Story2 before2 ? 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 <unk> hai1 . 	 	 Im2 doing2 great1 . kya1 aapne1 Toy1 Story2 pahle1 dekhi1 hai1 ?.
# 	didn't2 know2 he2 was2 the2 author2 	 	 muje1 , hai1 <unk> <unk> hai1 hai1 	 	 pata1 nahi1 tha1 vo1 ek1 author2 tha2.
# 	oh1 I1 should2 have2 know2 seeking2 vengence2 	 	 muje1 , hai1 <unk> <unk> hai1 hai1 	 	 Mujhe1 vengence2 ko1 dekhkar1 jankari1 mili1.
# 	It2 makes2 it2 almost2 more2 enjoyable2 since2 it2 is2 a2 new2 spin2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 ye1 isey2 almost2 zyada2 enjoyable2 bana2 deti1 hai1 kyunki1 ye1 ek1 naya1 spin2 hai1.
# 	that2 is2 important2 	 	 <unk> , hai1 	 	 Ye1 Important2 hai1.
# 	These2 storys2 based2 on2 true2 stories2 tend2 to2 always2 add2 so2 much2 stuff2 to2 keep2 it2 interesting2 that2 it2 kinda2 distorts2 history2 in2 my2 opinion2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mere2 opinion2 me2 true2 stories2 pe2 based2 ye2 story1 hamesha1 history1 ko1 distort2 karti1 hain1 use1 interesting2 banane1 ke1 liye1 ..
# 	I2 don't2 remember2 either2 . 	 	 mujhe1 , hai1 <unk> hai1 	 	 mujhe1 Yaad1 nahi1 hai1 ..
# 	yes1 he2 is2 the2 lead2 actor2 	 	 haan1 , hai1 hai1 hai1 	 	 han1 wo2 lead2 actor2 hai1.
# 	ive2 seen2 it2 quite2 a2 few2 times2 also2 	 	 haan1 , <unk> hai1 hai1 	 	 Maine1 ise1 kaee1 baar1 dekha1 hai1.
# 	Are1 there2 any2 reviews2 ? 	 	 <unk> , hai1 hai1 	 	 kuch2 reviews2 hein2 ?.
# 	LOKI1 	 	 <unk> 	 	 loki1.
# 	I2 think2 I2 have2 found2 my2 movie2 for2 tonight2 ! 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mujhe1 lagata1 hai1 ki1 mujhe1 aaj1 raat1 ke1 lie1 apanee1 philm1 mil1 gaee1 hai1 !.
# 	YES1 , The2 isle2 of2 Berk2 is2 their2 village2 , and2 they2 are2 afraid2 of2 the2 dragons2 because2 they2 steal2 their2 livestock2 , so2 when2 they2 come2 upon2 the2 dragons2 they2 usually2 kill2 them2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Haan1 , isle2 of2 Berk2 unka2 village1 hai1 aur1 wo1 dragons2 se2 darte1 hai1 kyuki1 wo1 unke2 livestock2 chura2 lete1 hai1 , to1 jab1 wo1 aate1 hai1 usually2 unko2 maar1 dete1 hai1 ..
# 	Hello1 ? 	 	 <unk> <unk> 	 	 hello1 ?.
# 	I2 expected2 more2 like2 the2 avengers2 where2 a2 bunch2 of2 heroes2 work2 together2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 main1 ise1 kuch1 avengers2 ke1 jaise1 expect2 kiya1 that1 jis1 may1 kuch1 heroes2 saath1 mai1 kaam1 karthe1 hai1.
# 	okay1 	 	 <unk> 	 	 acha1.
# 	Where2 are2 you2 located2 ? 	 	 <unk> , hai1 hai1 	 	 AAP1 KAHAAN1 HAIN1 ?.
# 	it2 was2 like2 a2 mother2 daughter2 love2 	 	 muje1 , <unk> <unk> <unk> hai1 hai1 	 	 ye1 ek1 mother2 daughter2 love2 ki1 tarah1 tha1.
# 	The2 Post2 was2 apparently2 trying2 to2 release2 papers2 detailing2 they2 30 year2 involvement2 of2 the2 US2 government2 int2 he2 Vietnam2 War2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 is2 post2 tho1 papers2 ka2 release2 karne1 ke1 liye1 try1 kar1 rahe1 the1 jo1 30 years2 involvement2 detailed2 hein2 us2 government2 ka1 aur1 vietnam2 war2 ka1.
# 	Monsters2 University2 is2 a2 sequel2 , I2 wondered2 if2 it2 is2 better2 than2 the2 first2 movie2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Monsters2 University2 ek2 sequel2 hai1 , mujhe1 wonder1 hoga1 ki1 agar1 se1 first2 movie2 se2 better1 hai1 ..
# 	have2 you2 Dunkirk2 ? 	 	 <unk> , hai1 hai1 	 	 kya1 tumhare1 paas1 Dunkirk2 hai1.
# 	interesting2 	 	 <unk> 	 	 kafi1 majedar1.
# 	Not2 only2 that2 , but2 Baz2 Lurhmann's2 direction2 was2 a2 magnificent2 sight2 to2 behold2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Yahi1 nhi1 baz1 lurhmann1 ki1 shandaar1 direction1 ne1 bhi1 roke1 rakha1.
# 	Or1 am1 i2 thinking2 of2 someone2 else2 / 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 ya1 mein1 kuch1 aur1 soch1 raha1 hoon1.
# 	this2 movie2 also2 may2 have2 done2 the2 best2 job2 out2 there2 on2 getting2 the2 hulk2 right2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Ho1 sakata1 hai1 ki1 is2 movie2 ne1 bhee1 hulk1 ko1 sahee1 kaam1 karane1 mein1 behatar1 kaam1 kiya1 ho1.
# 	The2 scene2 where2 Christy2 Lee2 says2 Facebook2 me1 is2 kinda2 funny2 , too2 . It2 certainly2 beats2 facesmash2 me2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Wo1 scene1 jaha1 Christy2 Lee1 bolti1 hai1 Facebook1 me1 funny2 type2 ka1 hai1 . Certainly2 facesmash2 me1 bolne1 se1 to1 accha1 hai1 ..
# 	hi1 	 	 hi1 	 	 hi1 namaste1.
# 	like2 	 	 <unk> 	 	 Pasand1.
# 	I2 had2 no2 idea2 this2 movie2 was2 actually2 based2 on2 a2 self-help2 book2 	 	 <unk> <unk> 	 	 Mujhe1 koi1 idea1 nahi1 tha1 ye1 movie2 actually2 ek2 self-help2 book2 k1 upar1 based1 hai1.
# 	She2 relies2 on2 love2 to2 stop2 war2 . 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 	 	 wo1 war2 band1 karne1 ke1 liye1 love1 par1 vishwas1 karti1 hai1.
# 	They2 both2 sound2 interesting2 . New2 York2 is2 a2 great2 place2 as2 well2 ! 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 dono1 hi1 interesting2 lag2 rage1 . new2 york1 bhi1 kaafi1 acchi1 jagah1 hai1.
# 	For2 me2 the2 movie2 is2 average2 . Nothing2 special2 . 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 hai1 	 	 mere1 liye1 tho1 is2 movie2 average2 hein1 .. kuch1 special1 nahi1.
# 	did2 you1 get2 access2 to2 the2 documents2 about2 the2 movie2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 hai1 	 	 kya1 tumhe1 movie1 ke2 documents2 ki2 access2 mili2 ?.
# 	or2 something2 	 	 <unk> , hai1 	 	 ya1 kuch1 kuch1.
# 	Yes2 , the2 plot2 sounds2 really2 good2 . Turing2 manages2 to2 decrypt2 the2 Nazi2 code2 machine2 , but2 the2 Nazis2 change2 the2 code2 every2 day2 . So1 they2 all2 realize2 they2 can't2 act2 on2 every2 day's2 decrypted2 messages2 or2 the2 Nazis2 will2 know2 that2 their2 code2 machine2 is2 useless2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 haan1 , kathaanak1 vaastav1 mein1 achchha1 lagata1 hai1 . tyooring1 naajee1 kod1 masheen1 ko1 dikript1 karane1 ka1 prabandhan1 karata1 hai1 , lekin1 naajiyon1 ne1 har1 din1 kod1 badal1 diya1 . isalie1 ve1 sabhee1 mahasoos1 karate1 hain1 ki1 ve1 har1 din1 dikript1 kie1 gae1 sandeshon1 par1 kaam1 nahin1 kar1 sakate1 hain1 ya1 naajiyon1 ko1 pata1 chal1 jaega1 ki1 unakee1 kod1 masheen1 bekaar1 hai1 ..
# 	He2 would2 be2 so2 lost2 without2 the2 	 	 mujhe1 , hai1 <unk> hai1 hai1 	 	 voh1 lost1 hote1 unke1 bina1.
# 	I2 think2 I2 would2 love2 it2 as2 well2 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 <unk> 	 	 Mujhe1 lagta1 hai1 mujhe1 bhi1 baht1 achhi1 lagegi1.
# 	I2 think2 I2 lost2 you2 somewhere2 in2 the2 conversation2 . Since2 it2 has2 been2 5 minutes2 without2 a2 response2 from2 you1 , I2 am2 going2 to2 abandon2 the2 discussion2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 I2 think2 maine1 tumhe1 loose1 kar1 diya1 conversation2 mein1 . kyonki1 5 minutes1 hua1 tumse1 response2 nahin1 mila1 , main1 discussion2 ko1 abandon1 karta1 hoon1 ..
# 	Well2 it2 was2 made2 in2 2016 	 	 muje1 , <unk> <unk> <unk> hai1 	 	 haan1 tho1 yeh1 2016 me1 aaya1.
# 	What2 about2 LA1 LA1 land1 ? Have2 you2 seen2 that2 ? 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 <unk> hai1 . 	 	 what2 about2 LA1 LA1 land1 ? kya1 tumne1 vah1 dekha1 he1 ?.
# 	Another2 said2 , " is2 too2 calculated2 to2 reflect2 today's2 ragged2 , tenuous2 sociopolitical2 climate2 ." 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 DUSRA1 KAHA1 KI1 ," AAJKAL1 KA1 RAGGED1 THO1 THODA1 REFLECT1 HEIN1 CALCULATE1 KARNE1 PE1 , TENUOUS1 SOCIOPOLITICAL1 CLIMATE2 .".
# 	What2 is2 your2 rating2 for2 Frozen2 ? 	 	 muje1 , hai1 hai1 hai1 	 	 tumhari1 rating1 kya1 hai1 Frozen2.
# 	so2 you2 are2 fan2 of2 these2 superhero2 movies2 as2 well2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 hai1 hai1 	 	 So1 tum1 bhi1 in1 superhero2 movies2 ke1 fan1 ho1 ?.
# 	It2 either2 has2 to2 be2 Sven2 or2 Christophe2 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 	 	 muje1 toh1 sven1 ya2 christophe2 pasand1 hein1.
# 	I2 don't2 believe2 Netflix2 has2 it2 , but2 worth2 checking2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 MAIN1 NETFLIX2 ME1 BAROSA1 NAHI1 KARTA1 , PAR1 CHEK1 KARNA1 HAI1.
# 	in2 the2 end2 , she2 chooses2 the2 lower2 class2 guy2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 akhir1 mein1 , wo1 lower2 class2 ladke1 ko1 choose1 karti1 hai1.
# 	this2 movie2 entered2 the2 Classics2 	 	 mujhe1 , hai1 <unk> hai1 	 	 Yah1 movie2 classic2 m2 enter2 kr1 gayi1.
# 	there2 is2 a2 scene2 where2 aurora2 is2 a2 little2 girl2 and2 she2 goes2 up2 to2 maleficent2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 ek1 scene1 hai1 jisme1 aurora1 choti1 ladki1 hai1 aur1 wo2 maleficent2 ke1 paas1 jati1 hai1.
# 	lol1 , I1 found2 that2 funny2 , Rocky2 with2 robots2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 lol1 , mujhe1 woh1 bahut1 funny1 lagi1 , Rocky2 with2 Robots2.
# 	Yeah1 - I2 wanted2 to2 talk2 about2 it2 because2 I2 like2 how2 David2 Fincher2 directed2 it2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Yeah1 - me1 uske1 baare1 me1 baat1 karna1 chahta1 hun1 , jaise1 David2 Fincher2 ne2 ise1 direct1 kiya1 mujhe1 pasand1 aaya1 ..
# 	i1 mean2 , he2 gets2 paid2 , but2 it's2 not2 something2 he2 wants2 to2 do1 . This2 happens2 in2 life2 a2 lot2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mera1 matlab1 hai1 , usko1 pay1 mila1 lekin1 wo1 ye1 nahi1 karna1 chahta1 . Life1 mein1 aisa1 bahut1 hota1 hai1.
# 	did2 you1 see2 it2 ? 	 	 <unk> , hai1 hai1 	 	 AAP1 DEKHE1 ?.
# 	do1 you2 recommend2 it2 ? 	 	 <unk> , hai1 hai1 	 	 kya1 aap1 isakee1 siphaarish1 karate1 hain1 ?.
# 	They2 tried2 to2 kill2 John2 so2 he2 was2 after2 the2 whole2 sindicate2 and2 raced2 to2 the2 Helicopter2 that2 Viggo2 was2 trying2 to2 escape2 in2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Unhone1 John1 ko1 maarne1 ki1 try1 ki1 so1 wo1 whole2 syndicate2 ke1 peeche1 tha1 aur1 jis1 Helicopter2 mein2 Viggo2 escape2 karne1 ki1 try1 kar1 raha1 tha1 uski1 taraf1 bhaaga1 ..
# 	Every1 movie2 with2 a2 fraternity2 / sorority2 always2 contains2 ' Kappa2 . ' Ever2 notice2 that2 ? 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 kappa2 ko1 saari1 movies1 mein2 fraternity2 / sorority2 hein2 .. kya1 aap1 notice1 nahi1 kiya1.
# 	Animated2 ??? 	 	 <unk> , hai1 	 	 Kya1 yeh1 Animated1 hai1 ???.
# 	Yes2 for2 sure2 . I2 like2 it2 . 	 	 muje1 , <unk> <unk> <unk> hai1 hai1 	 	 Han1 bilkul1 , mujhe1 wo1 pasand1 hai1 ..
# 	why2 let2 chat2 	 	 <unk> , hai1 	 	 Kyu1 chalo1 chat1 karte1 hai1.
# 	No2 have2 you2 ? is2 that2 the2 end2 ? 	 	 mujhe1 , hai1 hai1 hai1 hai1 	 	 nahi1 yar1 .. aap1 ? aur1 end1 kya1 hein1 ?.
# 	I1 love1 war2 movies2 , especially2 ones2 based2 on2 historical2 events2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mujhe1 warmovie1 pasant1 hai1 , zyathathar1 pouranic2 sambhav1.
# 	I1 know2 they2 are2 too1 funny1 . Hiccup2 is2 a2 great2 nickname2 though2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Mujhe1 pata1 hai1 bahut1 funny1 hai1 . waise1 Hiccup1 bahut1 badhiya1 nickname2 hai2 ..
# 	What's2 the2 rotten2 tomatoes2 score2 ? 	 	 mujhe1 , hai1 hai1 hai1 	 	 sada1 hua1 tamaatar2 skor2 kya1 hai1 ?.
# 	I'd2 love2 to2 tell1 you2 but2 I2 don't2 have2 the2 page2 with2 the2 plot2 summary2 anymore2 , haha1 . :)2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mein1 bataana1 toh1 chahataa1 hoon1 par1 mere1 pas1 woh1 page1 nahin1 hain1 jisme1 plot2 summary2 thi1 , haha1 :)2.
# 	Batman2 and2 Superman2 are2 enemies2 in2 this2 film2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 hai1 	 	 Kya1 Batman1 aur1 Superman1 is2 film1 me2 enemies2 hai2 ?.
# 	How2 did2 you2 like2 Iron2 Man2 ? 	 	 muje1 , hai1 hai1 hai1 	 	 are2 iron2 man1 ko1 kaise1 pasand1 aaya1 ?.
# 	How2 do1 you2 feel2 about2 the2 movie2 ? Care2 to2 share2 a2 little2 bit2 ? 	 	 muje1 , hai1 <unk> ki1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 tumhe1 movie1 ke1 bare1 me1 kaisa1 laga1 ? bata1 sakte1 ho1 thoda1 ?.
# 	He2 looks2 like2 the2 villian2 commander2 from2 the2 newer2 Star2 Wars2 movies2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Naye1 star2 wars2 movie2 me1 wo1 villian2 commander2 ke1 jesa1 dikh1 raha1 tha1.
# 	Yeah1 , the1 best2 film2 in2 modern2 animation2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Haan1 , modern2 animation2 mein1 best2 film1 hai1 ..
# 	They2 get2 really2 lucky2 several2 times2 . 	 	 mujhe1 , <unk> <unk> hai1 hai1 	 	 Wo1 bahut1 lucky1 ban1 gaye1 kaafi1 baar1.
# 	98% on2 Rotten2 Tomatoes2 ! 	 	 haan1 , hai1 <unk> hai1 	 	 Rotten2 Tomatoes2 pe2 98%..
# 	they2 make2 similar2 animated2 movies2 	 	 mujhe1 , hai1 <unk> hai1 	 	 VOH1 THO1 SIMILAR1 ANIMATED2 MOVIES1 BANATE1.
# 	the2 all2 star2 cast2 really2 helped2 too2 	 	 muje1 , <unk> <unk> <unk> hai1 	 	 Sabhe1 star2 cast2 ne2 vaastav1 mein1 bahut1 madad1 ke1 ..
# 	Just2 starting2 at2 a2 new2 high2 school2 , being2 an2 outsider2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Just1 naye1 high2 school2 me2 start1 karna1 , ek1 outsider2 hoke1.
# 	Hi1 have2 you2 seen2 Wonder2 Woman2 yet2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 	 	 hi1 kya1 tumne1 wonder1 woman2 dekha1 hai1 ab1 tak1 ?.
# 	Who2 is2 the2 enemy2 in2 the2 movie2 ? 	 	 mujhe1 , hai1 hai1 hai1 	 	 iss1 movie2 me1 dushman1 koun1 tha1 ?.
# 	Yeah1 I'm1 sure2 that2 wasn't2 explained2 as2 well2 as2 it2 should2 have2 , but2 they2 probably2 needed2 to2 get2 to2 the2 bang1 bang2 scenes2 faster2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Yeah1 , I1 am2 sure2 that2 wasn't2 explained2 jaisse2 hona1 chaiiya1 tha1 , par1 ho1 sakta1 hai1 they2 needed2 to2 get2 to2 the2 bang1 bang2 scenes2 faster2.
# 	Yes1 he2 has2 very2 good2 humor2 and2 acts2 with2 ease2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Han1 uske1 pass1 bahut1 accha1 humor1 hai1 aur1 wo1 bahut1 ease1 se2 work1 karta1 hai1.
# 	I2 enjoyed2 his2 movies2 	 	 haan1 , hai1 hai1 	 	 Maine1 uski1 movies1 ko2 enjoy2 karta1 hun1.
# 	bounty2 on2 the2 killer2 shark2 	 	 haan1 , hai1 hai1 	 	 hatyaara1 shaark1 par1 inaam1.
# 	Same1 here2 ! I2 honestly2 felt2 bad2 for2 Kevin2 at2 first2 seeing2 as2 how2 he2 was2 ridiculed2 by2 his2 siblings2 / cousins2 before2 being2 left2 behind2 . Like1 you1 , i2 could2 relate2 as2 well2 to2 the2 ridicule2 aspect2 of2 it2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 yaha1 bhi1 ! muje1 honestly2 kevin2 ke1 liye1 bura1 laga1 kyon1 ki1 pehele1 baar1 use1 dekha1 tho2 ridiculed2 mein2 uska1 siblings2 yaani2 cousins2 tho2 uska1 picha1 chod1 diya1 . aapke1 tarah1 , tho1 mein1 us2 ridicule2 ka2 aspect1 se2 relate2 kar1 raha1 tha1.
# 	totally2 agree2 	 	 <unk> , hai1 	 	 bilkul1 agree1.
# 	Yes1 ! And1 Keanu2 Reeves2 did2 such2 a2 great2 job2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 haan1 aur1 Keanu2 Reeves2 tho1 ache1 job1 kiya1.
# 	You2 can2 probably2 see2 it2 on2 Netflix2 . 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 	 	 kya1 yeh1 netflix2 mein2 dekh1 sakthe1 ?.
# 	imdb2 	 	 <unk> 	 	 imdb2.
# 	what2 about2 you2 ? 	 	 <unk> , hai1 hai1 	 	 apke1 baare1 me1 kya1 ?.
# 	That's2 Adrianne2 Palicki2 	 	 <unk> , hai1 hai1 	 	 Wo1 Adrianne2 Palicki2 hai1.
# 	I2 do1 . I2 get2 real2 into2 them2 and2 try2 to2 dig2 up2 as2 much2 info2 as2 I2 can2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 haan1 yar1 .. muje1 tho1 is2 film1 ka1 info1 chahiye1 tho1 mein1 sab1 info2 collect2 kar1 loonga1.
# 	revenge2 thrillers2 are2 intense2 	 	 haan1 , hai1 hai1 	 	 revenge2 thrillers2 tho2 badi1 intense2 hein2.
# 	I2 think2 if2 Patty2 Jenkins2 directs2 a2 sequel2 , it2 would2 be2 as2 good2 as2 the2 first2 one2 . She2 did2 a2 great2 job2 with2 this2 movie2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mujhe1 lagata1 hai1 ki1 agar1 patty2 jenkins2 ek2 seekval1 ka1 nirdeshan1 karatee1 hai1 , to1 yah1 pahale1 vaale1 kee1 tarah1 achchha1 hoga1 iss1 movie1 ke1 saath1 unhonne1 bahut1 achchha1 kaam1 kiya1 ..
# 	How2 are2 you1 ? 	 	 <unk> , hai1 hai1 	 	 Kaise1 ho1 ?.
# 	it2 is2 interesting2 how2 he2 suggested2 getting2 rid2 of2 " the2 " 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 ye1 interesting2 hai1 kaise1 usne1 ' the1 ' se2 rid1 karne1 ka1 suggest2 ..
# 	Its2 based2 on2 Dunkirk's2 evacuation2 during2 WWII2 . 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 	 	 ye1 during2 WWII2 Dunkirk's2 evacuation2 par2 based2 he2 ..
# 	I2 really1 want2 to2 watch2 this2 movie2 I2 think2 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 hai1 	 	 Me1 really1 ye1 movie2 watch2 karna1 chahuga1 , I1 think2.
# 	Yes2 it's2 about2 The2 social2 Network2 	 	 muje1 , hai1 <unk> <unk> hai1 hai1 	 	 Han1 ye1 The2 social2 Network2 ke1 baare1 mein1 hai1.
# 	so2 I2 think2 it2 is2 already2 in2 DVD2 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 <unk> 	 	 mujhe1 lagta1 hai1 ye1 dvd2 mai1 pehle1 se1 hi1 hai1.
# 	The2 Minions2 provide2 an2 extra2 dose2 of2 humor2 too1 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 The2 minions2 ne2 humor1 ko1 extra2 dose2 provide2 kiya1 ..
# 	What2 I2 know2 is2 that2 Rotten2 Tomatoes2 named2 it2 in2 its2 " Top2 50 Greatest2 Teen2 Comedies2 ". 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Mujhe1 pata1 hai1 k1 Rotten2 Tomatoes2 ne2 use1 apni1 " Top1 50 Greatest2 Teen2 Comedies2 " me2 dala1 hai1.
# 	Im2 guessing2 he2 has2 the2 leading2 role2 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 <unk> 	 	 mujhe1 lagtha1 hai1 achhi1 role1 hai1 ..
# 	Do1 you2 have2 any2 other2 favorite2 film2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 	 	 apke1 pas1 khoie1 pasand2 film1 hai1.
# 	He2 killed2 it2 with2 this2 one2 	 	 mujhe1 , hai1 <unk> <unk> <unk> hai1 	 	 IS1 SE1 VAH1 USKO1 MAAR1 DIYA1.
# 	I2 also2 think2 it's2 a2 little2 bit2 inspired2 by2 rock2 em2 sock2 em2 robots2 , an2 old2 toy2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mere1 khayaal1 se1 yeh1 inspire2 hui1 he1 rock2 em2 sock2 em2 robots2 , ek1 purani1 toy1.
# 	Thanks2 for2 the2 conversation2 	 	 haan1 , hai1 hai1 	 	 conversation2 ke1 liye1 thanks1.
# 	yes1 i1 really2 did2 not2 care2 for2 the2 third2 one2 i2 never2 seen2 it2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> . 	 	 yes1 mai1 really2 care2 nahi1 karti1 third2 one2 ke1 baare1 me1 , maine1 wo1 kabhi1 dekhi1 nahi1.
# 	What2 is2 it2 about2 ? 	 	 <unk> , hai1 hai1 	 	 yah1 kis1 baare1 mein1 hai1 ?.
# 	This2 movie2 has2 something2 for2 everyone2 ! I2 highly2 recommend2 it2 :)2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 is2 movie2 mein1 tho1 sab1 hein1 . mein1 tho1 yeh1 recommend2 jarur1 karunga1.
# 	improv2 doesn't2 suit2 me1 	 	 mujhe1 , hai1 <unk> hai1 	 	 improv1 mujhpar1 jamta1 nahi1.
# 	Wolf2 of2 Wall2 street2 is2 pretty2 famous2 in2 the2 US2 . 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 	 	 VULPH2 OPH2 VOL1 SADAK1 AMERIKA1 MEIN1 BAHUT1 PRASIDDH1 HAI1 ..
# 	It's2 hard2 to2 believe2 this2 is2 Disney's2 53rd2 animated2 feature2 film2 ! I'd2 find2 it2 difficult2 to2 even2 name2 that2 many2 Disney2 animated2 features2 ! 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 muje1 yakin1 hi1 nahi1 hota1 ki1 yeh1 Disney1 ka2 53rd2 animated2 feature2 film2 hein1 ! muje1 kahi1 Disney2 animated2 features2 toh2 yaad1 hi1 nahi1 hein1.
# 	they2 get2 kill2 at2 the2 movies2 after2 bruce2 wants2 to2 leave2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 ve2 films2 mein1 maarana1 chhod1 dete1 hain1 , jab1 broos1 kill1 karna1 nahi1 chahta1 hain1.
# 	I2 agree2 . John2 Goodman2 was2 a2 great2 choice2 for2 Sulley2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mein1 maantha1 hoon1 , john1 goodman2 ache2 choice2 hei2 sulley1 keliye1.
# 	REALLY1 	 	 <unk> 	 	 VAASTAV1 ME1.
# 	Whose2 journey2 did2 you2 find2 most2 compelling2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 hai1 	 	 aapane1 kisakee1 yaatra1 ko1 sabase1 adhik1 sammohak1 paaya1 ?.
# 	That's2 what2 I'm2 doing2 in2 the2 fall2 ! I'm2 really2 looking2 forward2 to2 camping2 there2 ! 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Wahee1 to1 main1 kar1 rahaa1 hoon1 is2 fall2 mein1 ! Main1 to1 intezar1 kar1 raha1 hoon1 wahaan1 camping1 ka1 !.
# 	I2 wasn't2 aware2 that2 there2 were2 so2 many2 different2 types2 of2 sharks2 so2 near2 to2 the2 shore2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mujhe1 pata1 nahin1 tha1 ki1 kinaare1 ke1 paas1 itane1 saare1 different2 type2 ke1 sharks2 the2 ..
# 	Yeah1 that's2 very2 true2 . I2 would2 love2 it2 if2 someday2 we2 could2 really2 have2 virtual2 reality2 like2 that2 . It2 would2 be2 so2 much2 fun2 to2 be2 able2 to2 really2 feel2 like2 you're2 a2 super1 hero1 ! 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 haan1 voh1 tho1 sach1 hein1 ... ab1 tho1 nahi1 lekin1 jarur1 yek1 din1 muje1 pasand1 aayaga1 .. super1 hero1 ke1 tarah1 feel1 karna1 tho1 fun1 hein1.
# 	oh1 wow1 	 	 <unk> 	 	 oh1 wow1.
# 	You2 definitely2 need2 surround2 sound2 . 	 	 mujhe1 , hai1 <unk> hai1 	 	 tumko1 surround2 sound2 ki1 bahut1 jayada1 jarurat1 hai1 ..
# 	Is1 the2 movie2 in2 theaters2 	 	 mujhe1 , hai1 <unk> hai1 	 	 kya1 ye1 movie2 theaters2 me1 hai1.
# 	I2 feel2 like2 they2 dont2 make2 movies2 like2 that2 anymore2 , like2 action2 movies2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Mujhe1 lagta1 hain1 woh1 ab1 iski1 tarah1 do1 not2 make2 movies2 anymore2 , like2 action2 movies2 ..
# 	Have2 you2 seen2 it2 ? 	 	 <unk> , hai1 hai1 	 	 kya1 tumne1 isko1 dekha1 hai1 ?.
# 	it2 ' s2 historical2 political2 thriller2 ... 	 	 mujhe1 , hai1 <unk> hai1 	 	 yah1 yek1 rajnaitk1 thriller2 hai1.
# 	You2 add2 something2 more2 to2 the2 movie2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 hai1 	 	 AAP1 MOVIE1 PAR1 KUCH1 AUR1 KAAM1 KAR1 SAKTHE1 HO1.
# 	I2 like2 all2 the2 small2 details2 in2 the2 movie2 , and2 how2 gru2 evolves2 over2 time2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Mujhe1 movie1 ki1 har1 chhoti1 details1 achhi1 lagi1 , aur1 kaise1 time1 ke1 saath1 gru1 evolves2 ..
# 	I2 generally2 like2 to2 see2 movies2 that2 are2 so2 popular2 among2 my2 friends2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Mujhe1 generally1 wo2 movie2 pasand1 hai1 jo1 mere1 friends2 mei1 popular2 hi1.
# 	Thefacebook2 is2 just2 rotten2 . It2 seems2 like2 Zuckerberg2 really2 shafted2 everyone2 else2 in2 the2 situation2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Thefacebook2 to1 bilkul1 bekaar1 hai1 . Aisa1 lagta1 hai1 Zuckerberg2 ne2 sahi1 me1 dusre1 logo1 ki1 leli1.
# 	so2 he2 find2 he2 whoever2 did2 that2 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 . 	 	 TOA1 WAH1 DHOOND1 LEGA1 WUH1 KISNE1 KIYA1 HAI1.
# 	He2 played2 Gobber2 the2 Belch2 , who2 was2 the2 training2 masters2 of2 the2 young2 warriors2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 unhonne1 gobar1 da2 belch2 kee1 bhoomika1 nibhaee1 , jo1 yuva1 yoddhaon1 ke1 prashikshan1 ke1 svaamee1 the1.
# 	What2 was2 the2 name2 of2 the2 Pan-American2 airline2 pilot2 ? 	 	 <unk> , hai1 hai1 	 	 Pan-American2 airline2 ke2 pilot2 ka1 naam1 kya1 tha1 ?.
# 	It's2 a2 sci-fi2 movie2 and2 i2 don't2 typically2 watch2 those2 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 <unk> . 	 	 yah2 sci-fi2 moivehai2 mai1 eashi1 movi2 pasand1 nahi1 karta1.
# 	The2 critics2 also2 advise2 to2 put2 aside2 any2 literary2 agenda2 to2 best2 enjoy2 the2 movie2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 critics2 ne1 bhi1 use1 advice2 kiya1 , ussed2 literary2 agenda2 ko1 side1 rakhar1 , us1 movie1 ka1 best2 enjoy2 karo1.
# 	I2 am2 looking2 forward2 to2 adding2 it2 to2 my2 list2 of2 movies2 to2 watch2 . 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mai1 is1 movie1 ko1 apni1 dekhi1 jaane1 wali1 list1 me2 add1 karne1 ke1 baare1 soch1 raha1 hu1 ..
# 	no2 please2 tell1 me2 a2 little2 bit2 about2 it2 	 	 mujhe1 , hai1 <unk> hai1 hai1 	 	 Nahi1 , Mujhe1 uske1 bareme1 thoda1 aur1 bataiye1.
# 	I2 hope2 that2 Morgan2 Freeman2 is2 actually2 G-d2 in2 reality2 , if2 there2 is2 one2 . 	 	 muje1 , hai1 <unk> <unk> hai1 hai1 	 	 Mujhe1 lagta1 hai1 Morgan2 Freeman2 sach1 mein1 ek1 G-d1 hai1 , agar1 wahan1 hai1 to1 ..
# 	Probably2 helps2 that2 he2 was2 young2 . You're2 braver2 and2 more2 confident2 at2 that2 age2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 probably2 yeh1 tho1 young1 hein1 .. aap1 tho1 braver2 aur1 jyada1 confident1 hon2 in2 age2 mein1 bhi1.
# 	just2 recently2 for2 the2 first2 time2 	 	 haan1 , hai1 <unk> hai1 	 	 recently2 pehli1 baar1 k1 liye1.
# 	And2 the2 budget2 was2 190 mil1 . $ 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 	 	 BUDGET1 THO2 190MILLION2 $ THA2.
# 	I2 agree2 . I2 think2 the2 email2 system2 was2 less2 personal2 than2 how2 God2 would2 actually2 answer2 prayers2 in2 reality2 . However2 , at2 that2 point2 I'm2 sure2 he2 was2 overwhelmed2 . How2 would2 you2 answer2 everyone's2 prayers2 if2 you2 had2 to2 be2 God2 ? 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 haan1 ,... ab1 sabhi1 update1 hogaye1 tho1 kyon1 God1 bhi1 apne1 email1 system2 se1 kyon1 nahi1 chaleye1 ... however2 , voh2 tho1 badi2 overwhelmed2 they2 .. kya1 voh1 saari1 prayers2 sunthe2 , jaise1 God1 ke1 tarah1 ?.
# 	I2 tend2 to2 agree2 . 	 	 mujhe1 , hai1 <unk> hai1 	 	 mein1 bhi1 agree1 karunga1.
# 	He2 also2 killed2 the2 dad2 because2 the2 dad2 was2 mad2 that2 his2 son2 died2 and2 tried2 to2 kill2 him2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Esne1 apne1 papa1 ko1 mara1 hai1 kyoki1 pana1 pagal1 the1 wo1 soch1 rahe1 the1 ki1 beta1 unko1 mar1 dega1 ..
# 	That2 was2 a2 plot2 detail2 I2 definitely2 missed2 . Must1 have2 been2 an2 early2 scene2 in2 the2 movie2 . 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 voh1 plot2 detail2 tho1 mein2 definitely2 missed2 karunga1 .. is1 movie2 mein2 early2 scene2 honge1.
# 	She2 is2 his2 pats2 lover2 and2 tom's2 wife2 - joel2 edgerton2 	 	 <unk> , hai1 	 	 voh1 uska1 pats1 lover1 thi1 aur1 toms2 ka2 wife2 - joel2 edgerton2.
# 	it2 was2 a2 good2 movie2 though2 	 	 mujhe1 , hai1 hai1 	 	 yaddhyapi1 yah1 good2 movie2 thi1 ..
# 	I2 believe2 it2 . I2 remember2 reading2 about2 the2 lawsuits2 when2 they2 were2 filed2 . I2 think2 they2 have2 great2 lawyers2 to2 protect2 themselves2 though2 ... 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mujhe1 yaqeen1 hai1 . mujhe1 yaad1 hai1 maine1 padha1 tha1 jub2 lawsuits2 file2 hue1 thay1 . mere1 khayal1 se1 unke1 pass1 khud1 ko1 bachanay1 ache2 lawyers2 hai1.
# 	# firstworldproblems2 	 	 <unk> 	 	 # firstworldproblems2.
# 	Cumberbach2 does2 a2 great2 job2 acting2 . 	 	 muje1 , <unk> <unk> <unk> hai1 	 	 kamal1 ki1 acting1 ki1 hai1 Cumberbach2 ne2 ..
# 	Probably2 could2 become2 POTUS2 these2 days2 . 	 	 mujhe1 , hai1 <unk> hai1 	 	 probably2 voh1 POTUs1 ban1 jaathe1 hein1.
# 	Michael2 Caine2 must2 be2 Alfred2 . I2 can't2 see2 him2 playing2 anyone2 else2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Michael2 Caine2 jarur2 Alfred2 hoga1 . Mai1 use1 koi1 aur1 role2 play2 karte1 dekh1 hi1 nahi1 sakta1 ..
# 	The2 movie2 tries2 to2 stop2 the2 war2 not2 be2 in2 it2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 movies1 mai1 war1 rokne1 ke1 bare1 mai1.
# 	I2 just2 remember2 my2 niece's2 birthday2 . Must've2 heard2 that2 song2 200 times2 ... in2 a2 row2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mujhe1 bas1 apanee1 bhateejee1 ka1 janmadin1 yaad1 hai1 . ek1 pankti1 mein1 200 baar1 us1 geet1 ko1 suna1 hoga1.
# 	This2 Real2 Steel2 movie2 has2 Hugh2 Jackman2 in2 it2 . He's2 not2 b1 ad1 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 real2 steel2 movie2 mei2 Hugh2 Jackman2 hai1 . Vah1 bura1 nahi1 hai1 ..
# 	Who2 is2 the2 director2 ? 	 	 <unk> , hai1 hai1 	 	 Director1 kaun1 hai1 ?.
# 	The2 actors2 are2 really2 great2 and2 you2 probably2 know2 all2 of2 them2 . Ben2 Affleck2 , Henry2 Cavill2 , Amy2 Adams2 , and2 Jesse2 Eisenberg2 to2 name2 a2 few2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Actors2 sahi2 me1 acche1 hai1 aur1 tum1 probably1 sabhi1 ko1 jaante1 ho1 . Unme1 se1 kuch1 Ben2 Affleck2 , Henry2 Cavill2 , Amy2 Adams2 , and2 Jesse2 Eisenberg2 hai2.
# 	oh1 goodness1 	 	 <unk> , 	 	 oh1 goodness1.
# 	Yes1 .. 	 	 <unk> 	 	 haan1 ...
# 	Who2 else2 is2 in2 the2 movie2 ? 	 	 muje1 , hai1 hai1 hai1 	 	 AUR1 KON1 HEIN1 IS1 MOVIE1 MEIN1.
# 	First2 movie2 looks2 more2 like2 a2 documentary2 / war2 	 	 muje1 , hai1 <unk> <unk> hai1 hai1 hai1 	 	 Pehli1 movie1 bahut1 had1 tak2 documentary2 / war2 jaisi1 pratit1 hui1.
# 	I2 guess2 that2 time2 has2 passed2 . Nowadays2 most2 of2 the2 trade2 is2 digital2 I2 guess2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 muje1 lagtha1 , time2 tho1 chala1 gaya1 .. aajkal1 tho1 trade2 hi1 digital1 huva1.
# 	the2 bit2 at2 the2 end2 that2 showed2 what2 could2 have2 been2 actually2 made2 me1 sad1 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 end2 me1 jo1 dikhaya1 tha1 , wah1 mujhe1 actually1 kafi1 sad1 kar1 sakta1 tha1.
# 	Tuberculosis2 . 	 	 <unk> 	 	 Tuberculosis2 ..
# 	It2 was2 about2 a2 failed2 attack2 where2 British2 and2 Candian2 soldiers2 were2 trapped2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 ye1 ek1 haari1 huye1 akraman1 ke1 bare1 maim1 hai1 , jaham1 british1 aur1 candian1 sipahi1 fus1 gaye1 the1.
# 	Have2 you2 seen2 Gaslight2 ? 	 	 <unk> , hai1 hai1 	 	 kya1 tumne1 Gaslight1 dekhi1 hai1 ?.
# 	Which2 dragon2 was2 your2 favorite2 ? 	 	 haan1 , hai1 hai1 hai1 	 	 Konsa1 dragon2 aap1 ka1 pasandida1 hai1 ?.
# 	are2 there2 other2 marvel2 characters2 in2 the2 movie2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 hai1 	 	 koyi1 marvel2 characters2 hi2 kya1 movie2 me2 ?.
# 	There2 were2 a2 lot2 of2 suspenseful2 moments2 in2 the2 movie2 	 	 mujhe1 , hai1 <unk> hai1 hai1 	 	 Movie2 mein1 bohot1 saare1 suspense1 wale2 moments2 the2 ..
# 	Interesting2 , I2 think2 I2 will2 give2 the2 movie2 a2 chance2 and2 watch2 it1 , It2 seems2 worth2 my2 while2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Yeh1 to1 interesting2 hai1 , mujhe1 lagta1 hai1 ki1 mein1 ye1 movie1 dekhoonga1 , yeh1 mere1 time1 ke1 liye1 worth2 hai1.
# 	so2 this2 movie2 is2 more2 about2 the2 villan2 	 	 muje1 , hai1 <unk> hai1 hai1 hai1 	 	 Toh1 yeh1 movie1 zyadaya1 villan1 ke1 baare1 mein1 hai1.
# 	you2 too1 	 	 <unk> 	 	 Tumhe1 bhi1.
# 	hello1 	 	 hello1 	 	 hello1.
# 	Is1 it2 similar2 to2 the2 book2 ? 	 	 mujhe1 , hai1 hai1 hai1 	 	 kya1 yeh1 book1 ka2 similar2 hein2.
# 	I2 don't2 much2 care2 for2 review2 sites2 , I2 would2 rather2 watch2 a2 movie2 and2 judge2 it2 myself2 . 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 main2 saiton1 kee1 sameeksha1 karane1 ke1 lie1 bahut1 paravaah1 nahin1 karata1 , main1 ek1 philm1 dekhoonga1 aur1 ise1 khud1 jaj1 karoonga1 ..
# 	It2 seems2 so2 silly2 which2 makes2 it2 funny2 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 	 	 yeh1 tho1 silly2 hein1 yar1 .. tho1 kya1 aapko1 funny1 laga1.
# 	Does2 it2 mention2 how2 accurate2 the2 movie2 is2 as2 opposed2 to2 real-life2 events2 ; that's2 why2 I2 was2 asking2 if2 it2 was2 biographical2 as2 opposed2 to2 simply2 historical2 ? 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 kya1 yah1 ullekh1 karata1 hai1 philm1 vaastavik1 jeevan1 kee1 ghatanaon1 ke1 vipareet1 kitanee1 sahee1 hai1 ; isalie1 main1 poochh1 raha1 tha1 yadi1 yah1 keval1 aitihaasik1 ke1 vipareet1 jeevanee1 thee1 ?.
# 	And2 when2 he2 tries2 to2 be2 a2 pilot2 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 <unk> 	 	 aur1 jab1 voh1 pilot1 ko1 bhi1 trie2 kar1 raha1 tha1.
# 	i1 love1 action2 movies2 	 	 <unk> , hai1 hai1 	 	 Mujhe1 action2 films2 pasand2 hain1 ..
# 	No1 I1 can't1 haha1 	 	 <unk> , hai1 hai1 	 	 No1 , mai1 nahi1 kar1 sakta1 haha1.
# 	I2 think2 also2 where2 it2 is2 a2 movie2 about2 a2 mathematician2 , it2 kind2 of2 helps2 to2 add2 in2 some2 plot2 elements2 . I2 think2 this2 is2 unusual2 though2 as2 his2 life2 was2 so2 interesting2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 I2 think2 also2 yah1 movie1 ek2 mathematician2 ke1 baare1 men1 hai1 , plot1 me1 thode1 elements2 dalna2 helpful2 hai1 . par1 mujhe1 ye1 unusual2 laga1 kyonki1 uski1 life1 to2 waise1 hi1 itni1 interesting2 hai1 ..
# 	I2 liked2 this2 scene2 on2 the2 top2 of2 the2 Stark2 Industries2 building2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mujhe1 yeh1 scene1 on2 the2 top2 jyada1 pasand1 aayi1 stark2 industries2 building2 se1.
# 	Yes1 , it2 sounds2 like2 quite2 a2 story2 	 	 muje1 , hai1 <unk> <unk> hai1 hai1 	 	 haan1 , muje1 bhi1 is1 tarah1 ka1 story1 hi1 lag1 raha1 hein1.
# 	Maybe2 because2 i2 don't2 fancy2 them2 	 	 muje1 , <unk> <unk> <unk> hai1 	 	 Shayad1 because1 me1 use2 fancy2 nahi1 krta1.
# 	Looks2 like2 this2 movie2 is2 pretty2 heavily2 based2 on2 cartoon2 fraternities2 . 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> hai1 <unk> . 	 	 lagtha1 hein1 ki1 movie2 thoda2 heavily2 cartoon2 fraternities2 hoga2.
# 	Do1 you1 know2 if2 it2 won2 any2 major2 awards2 ? 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 hai1 hai1 . 	 	 Kya1 tumhe1 pata1 hai1 agar1 usne1 koi1 major2 awards2 jeete1 ?.
# 	It2 was2 written2 by2 Peter2 Benchley2 . 	 	 muje1 , <unk> <unk> <unk> hai1 	 	 Ye1 Peter2 Benchley2 write2 ki1 thi1 ..
# 	would2 you2 like2 to2 hear2 a2 bit2 about2 the2 plot2 	 	 muje1 , hai1 <unk> hai1 <unk> hai1 hai1 	 	 aur1 kuch1 plot1 ke1 baare1 mein1 sunna1 chayenge1.
# 	He2 founded2 the2 biggest2 social2 network2 the2 world2 has2 ever2 seen2 , but2 he2 seems2 like2 a2 person2 who2 people2 hate2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Usne1 duniya1 ka1 sabse1 bada1 social2 network2 banaya1 but1 wo1 ek1 aisa1 aadmi1 lagta1 hai1 jise1 log1 hate1 karte1 hai1.
# 	Do1 you2 think2 Ben2 Affleck2 makes2 a2 good2 Batman2 ? 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 hai1 hai1 . 	 	 Kya1 tumhe1 agta1 hau1 Ben2 Affleck2 acha2 Batman2 lagta1 hai1 ?.
# 	do1 you2 like2 animation2 movies2 ? 	 	 muje1 , hai1 hai1 hai1 	 	 kya1 aapako1 nimation2 movies2 pasand1 hain1 ?.
# 	Anyways2 sounds2 like2 a2 trash2 movie2 	 	 mujhe1 , hai1 <unk> hai1 	 	 anyways2 , yeh1 trash1 movies2 hein1.
# 	That2 is2 certainly2 interesting2 to2 know2 . I2 always2 wondered2 about2 it2 myself2 . Apparently2 , Saverin2 was2 the2 only2 consultant2 with2 any2 true2 to2 life2 information2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Ye1 janna1 jarur1 interesting2 hai1 . Main1 hamesha1 is1 bare2 me1 sochta1 tha1 . Apparently2 , Saverin2 akela2 consultant2 tha2 jiske1 paas1 koi1 true2 to2 life2 information2 thi2 ..
# 	i2 also2 think2 this2 movie2 has2 kind2 of2 served2 as2 a2 template2 for2 newer2 super2 hero2 movies2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Mujhe1 yah1 bhee1 lagata1 hai1 ki1 iss1 movie2 ne1 nae1 superhero2 movie1 ke1 lie1 ek1 tempalet1 ke1 roop1 mein1 seva1 kee1 hai1.
# 	He2 kept2 saying2 that2 the2 shrinking2 would2 wear2 off2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 voh1 bol1 raha1 tha1 ki1 are1 voh1 tho1 shrink2 ho1 ja1 raha1 hein1.
# 	So1 , what2 else2 did2 you2 like2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 	 	 to1 , aapako1 aur1 kya1 pasand1 aaya1 ?.
# 	Marvel2 put2 the2 project2 into2 production2 as2 its2 first2 self-financed2 film2 , with2 20th2 Century2 Fox2 as2 its2 distributor2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 marvel2 ne2 tho1 is2 project2 ka2 production1 pehla1 self2 financed2 film2 me1 daala1 , jo1 20th2 century2 fox2 ki2 distributor2 tha2.
# 	No2 that2 is2 not2 the2 case2 however2 he2 is2 manipulated2 into2 helping2 . By2 the2 way2 did2 I2 mention2 this2 is2 going2 to2 be2 the2 first2 time2 batman2 and2 superman2 are2 in2 a2 movie2 together2 ? 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Nahi1 , waise1 nahi1 hota1 hai1 but1 wo2 use2 help2 karne1 me1 manipulate2 ho1 jata1 hai1 . By2 the2 way1 kya1 maine1 mention1 kiya1 ye1 pahli1 movie1 hai1 jisme1 batman1 aur1 superman1 saath1 me1 hai1 ?.
# 	have2 you2 heard2 any2 reviews2 of2 it2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 	 	 Kya1 tumne1 uske1 koi1 review2 sune2 hai1 ..
# 	And2 what2 do2 they2 know2 about2 science2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 hai1 	 	 aur1 ve1 vigyaan1 ke1 baare1 mein1 kya1 jaanate1 hain1 ?.
# 	Yeah1 , it2 is2 . And2 expensive2 ! 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 	 	 sahi1 hai1 . bahut1 mahanga1 hai1.
# 	I2 did2 when2 it2 came2 out2 years2 ago2 , just2 never2 thought2 to2 look2 at2 the2 voice2 acting2 . 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mene1 kiya1 jab1 ye1 kuch1 saal1 pahale1 aa1 gai1 thi1 , mene1 nahi1 socha1 tha1 ki2 voice2 acting1 hogi1 ..
# 	Yeah2 it's2 so2 crazy1 haha1 . makes1 you2 feel2 old2 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 <unk> hai1 . 	 	 Haan1 ye1 bahut1 crazy1 hai1 . khud1 ko1 old2 feel2 hota1 hai1.
# 	To1 be2 honest2 , I2 find2 shark2 movies2 to2 be2 terrifying2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 sach1 kahoon1 , to1 mujhe1 shaark1 philmen1 bhayaanak1 lagatee1 hain1 ..
# 	IT1 IS1 BASED1 ON2 DC2 COMISC2 . THE1 DISTRIBUTED1 BY1 WAMER2 BROS2 . PICTURES1 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 yah1 dc2 comic2 par2 aadharit1 hai1 . wamer2 bros2 pictures2 ne2 vitarit1 kiya1 hai1.
# 	yeah1 , it2 really2 is2 . i1 have2 liked2 almost2 all2 of2 nolans2 movies2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 yes1 , yah1 really1 hai1 . maine1 nolan1 ki2 almost2 sabhi2 movies2 ko1 pasand1 kiya1 hai1.
# 	i1 was2 actually2 completely2 fooled2 	 	 haan1 , hai1 <unk> hai1 	 	 completely2 fool2 ban1 gaya1 tha1 actually1 me1.
# 	86% is2 a2 fair2 rating2 . I2 felt2 that2 this2 movie2 was2 excellent2 but2 somewhat2 ' heady2 '. I2 could2 see2 why2 it2 isn't2 everyone's2 cup2 of2 tea2 . What2 rating2 would2 you2 give2 Inception2 ? 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 86% fair2 rating2 he2 . Mujhe1 laga1 ki1 ye1 movie2 excellent2 he2 but2 somewhat2 " heady2 " he2 . me1 dekh1 sakta1 hu1 ki1 kyu1 ye1 everyone1 ka2 cup2 of2 tea2 he1 . Tum1 Inception2 ko1 kya1 rating1 dete1 ?.
# 	i1 dont1 like2 how2 they2 changed2 it2 around2 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 	 	 muje1 tho1 uska1 aisa1 change1 hona1 bilkul1 pasand1 nahi1 hein1.
# 	Tony2 Stark2 " Genius2 , billionaire2 who2 has2 inherited2 the2 defense2 contractor2 from2 his2 father2 '... It2 couldn't2 happen2 in2 other2 part2 of2 the2 world2 :)2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Tony2 Stark2 " genius2 , billionaire2 jisne1 apne1 pita1 se2 defense2 contractor2 inherit2 kiya1 " aisa1 duniya1 k1 kisi1 aur1 part1 me1 ho1 hi1 nahi1 sakta1 :)2.
# 	Who2 is2 your2 favorite2 character2 in2 Despicable2 Me2 ? 	 	 mujhe1 , hai1 <unk> hai1 hai1 	 	 Tumhara1 favourite1 character2 kaun1 hai1 Despicable2 Me2 mein1 ?.
# 	No2 other2 than2 that2 you2 mentioned2 titanic2 	 	 mujhe1 , hai1 <unk> hai1 hai1 	 	 titanic2 ke1 behetar1 aur1 koi1 nahi1.
# 	This2 also2 sounds2 like2 that2 , I2 think2 , Brad2 pitt2 movie2 about2 underground2 fight2 venues2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 ye1 waisa1 lagta1 hai1 , I1 think2 , Brad2 Pitt2 ki1 movie2 underground2 fight2 venues2 ke1 baare1 mein1.
# 	Does2 Superman2 have2 a2 fight2 with2 kidnapper2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 hai1 	 	 Kya1 Superman2 kidnapper2 k2 sath1 ladta1 hai1 ?.
# 	No1 , I2 haven't2 . Tell1 me1 about2 it2 ? 	 	 muje1 , hai1 <unk> <unk> hai1 hai1 hai1 	 	 nahi1 , mein1 nahi1 dekha1 . aapke1 baare1 mein1 bolo1 ?.
# 	I2 totally2 agree2 	 	 <unk> , hai1 hai1 	 	 Main1 pura1 agree1 karta1 hu1.
# 	Yes1 , indeed2 they2 do2 . But2 the2 positive2 aspect2 about2 the2 movie2 Zootopia2 , is2 that2 although2 it2 is2 all2 imaginary2 , the2 film2 carries2 a2 message2 of2 acceptance2 that2 is2 thought-provoking2 	 	 <unk> , 	 	 Haa1 woh1 karte1 hain1 . Lekin1 Zootopia2 movie2 ki1 positive2 aspect2 hai1 ki2 although2 sab2 imaginary2 hai2 film1 ek1 acceptance2 message2 deti1 hai1 jo2 thought-provoking2 hai2.
# 	Will1 you1 see2 the2 next2 one2 ? 	 	 muje1 , hai1 hai1 hai1 hai1 	 	 AAP1 DOOSARA1 DEKH1 SAKTHE1 HO1 ?.
# 	can2 you1 be2 more2 specific2 ? 	 	 muje1 , hai1 hai1 hai1 	 	 kya1 tum1 or1 jyada1 specific2 bata2 sakte1 ho1 ?.
# 	I1 know1 . I2 think2 this2 was2 one2 of2 Speilbergs2 best2 films2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 i1 know1 . mere1 vichar1 se1 ye2 Speilbergs2 ki2 best2 films2 me2 se1 ek1 he1 ..
# 	I2 really1 want2 to2 watch2 this2 movie2 I2 think2 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 hai1 	 	 muje1 lagtha1 hein1 ki1 mein1 is2 movie1 ko1 jarur1 dekhunga1.
# 	It2 is2 interesting2 that2 Disney2 was2 able2 to2 add2 onto2 the2 history2 of2 works2 such2 as2 Beauty2 and2 the2 beast2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 yah1 dilachasp1 hai1 ki1 dijnee1 saundary1 aur1 jaanavar1 jaise1 kaaryon1 ke1 itihaas1 mein1 jodane1 mein1 saksham1 tha1.
# 	Both2 are2 good2 actors2 , Goslings2 more2 attractive2 . HA1 ! 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 dono1 achche1 actores1 hai2 , Gosling2 jyada2 attractive2 . HA1 !.
# 	what2 is2 your2 favorite2 part2 of2 the2 movie2 ? 	 	 mujhe1 , hai1 hai1 hai1 	 	 konsa1 part1 aapka1 favorite1 hein1 is2 movie2 mein1 ?.
# 	its2 so2 lovely2 	 	 <unk> , hai1 hai1 	 	 wo1 bohat1 lovely1 hai1.
# 	oh1 yeah1 me1 too1 . too1 much2 texting2 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 	 	 oh1 yeah1 mai1 bhi1 . Bahut1 jyada1 texting2.
# 	yeah1 	 	 <unk> 	 	 Ha1.
# 	I2 would2 have2 thought2 it2 was2 newer2 	 	 muje1 , <unk> <unk> <unk> hai1 	 	 Mujhe1 laga1 ye1 nayi1 hogi1 ..
# ...
# 	I2 think2 you2 would2 like2 it2 then2 . 	 	 mujhe1 , hai1 <unk> <unk> hai1 hai1 	 	 mujhe1 lagta1 hai1 tumhe1 tab1 accha1 lagega1.
# 	Yeah1 . Its2 very2 unpleasent2 . 	 	 mujhe1 , hai1 <unk> hai1 	 	 SAHI1 HAI1 . YEH1 EK1 ACHHI1 BAAT1 NAHIN1 HAI1.
# 	Good2 to2 hear2 . Sure2 , what2 about2 you2 ? 	 	 muje1 , hai1 <unk> hai1 <unk> hai1 hai1 	 	 Sunke1 accha1 laga1 . Sure1 , tum1 batao1 ..
# 	Yes2 , the2 end2 is2 surprising2 . The2 movie2 will2 keep2 you2 on2 the2 edge2 of2 your2 seat2 . 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 haan1 , end1 tho2 surprising2 hein2 .. movie2 tho1 badiya1 hein1.
# 	S1 I1 LIKE1 THIS1 FILM1 	 	 mujhe1 , hai1 <unk> hai1 	 	 mujhe1 ye1 film2 pasand2 hai1.
# 	Huh1 interesting2 	 	 <unk> <unk> 	 	 Huh1 interesting2 hai1.
# 	I2 don't2 like2 how2 they2 made2 a2 whole2 new2 story2 line2 . 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> . 	 	 Mujhe1 to1 bilkul1 hi1 pasand1 nahi1 aaya1 kaise1 unhone1 poori1 new2 story2 line1 bana1 di1 ..
# 	seems2 like2 Olga2 was2 born2 in2 Russia2 , so2 no2 , much2 better2 looking2 than2 Henry2 or2 Jane1 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 lagta1 hai1 Olga1 ka1 janam1 Russia1 me1 hua1 tha1 , so1 nahin1 , Henry2 or2 Jane1 ko1 dekhne1 se1 much2 better2 hai1.
# 	Would2 you2 like2 a2 movie2 recommendation2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 	 	 kya1 tum1 movie2 recommendation2 pasand1 karte1 ho1 ?.
# 	I2 really1 like2 Gary2 Oldman2 as2 Gordon2 . He2 plays2 a2 good2 cop2 really2 well2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Mujhe1 Gary2 Oldman2 as2 Gordon2 accha1 laga1 . Wo1 ek1 good2 cop2 accha1 play1 karta1 hai1.
# 	? 	 	 hello1 ? 	 	 ?.
# 	Really2 you2 think2 its2 forgettable2 ? 	 	 muje1 , hai1 <unk> hai1 	 	 really1 tumhe1 lagta1 hai1 ye1 forgettable2 hai1 ?.
# 	Huge2 bugdet2 did2 it2 make2 it2 back2 lol2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 hai1 	 	 huge2 budget2 na1 ? kya1 unko1 fir1 se1 mila1 ?.
# 	What2 year2 was2 it2 released2 ? 	 	 mujhe1 , hai1 hai1 hai1 	 	 Kon1 se1 year1 mei2 released2 hogi1 ?.
# 	Yes1 .. really2 	 	 <unk> , hai1 	 	 haan1 sach1.
# 	i2 also2 thought2 it2 was2 difficult2 for2 sebastian2 to2 take2 keith's2 offer2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mujhe1 bhi1 laga1 ki1 sebastian1 keo1 keith1 ka1 offer2 difficult2 laga2.
# 	Yeah1 , too2 many2 people2 relay2 on2 fb1 now2 ! 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> . 	 	 haan1 , jyada1 people1 fb1 mein1 hein1 ab1.
# 	What2 genre2 is2 La1 La1 land2 ? 	 	 muje1 , hai1 hai1 hai1 	 	 kya1 shailee1 la1 la1 bhoomi1 hai1 ?.
# 	I2 like2 action2 though2 like2 fighting2 	 	 muje1 , hai1 <unk> <unk> hai1 hai1 	 	 mujhe1 action1 aur1 ladai1 pasand1 hain1 ..
# 	My2 favorite2 movie2 genre2 is2 science2 fiction2 , but2 I2 do2 like2 a2 good2 comedy2 , or2 a2 good2 drama2 . If2 it's2 a2 good2 movie2 , I2 really1 don't1 care2 what2 genre2 it2 is2 . 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Meri1 favorite2 movie2 genre2 hai1 science2 fiction2 , but1 mujhe1 acchi1 comedy1 bhi1 acchi1 lagti1 hai1 , ya1 achha1 drama1 . Agar1 ye1 ek1 acchi1 movie1 hai1 , to1 main1 asal1 mein1 parwaah1 nhi1 krti1 ki1 ye1 kis2 genre2 ki1 hai1 ..
# 	Russell2 Brand2 was2 a2 great2 choice2 to2 play2 Dr2 . Nefario2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> . 	 	 Russell2 Brand2 ek1 acchhi1 choice1 tha2 Dr1 . Nefario2 play2 karne1 ke1 liye1 ..
# 	More2 about2 her2 internal2 battles2 than2 the2 WWI2 battles2 . very2 engaging2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Ye1 WWI2 se1 jyada1 uske1 internal2 battles2 ke1 bare1 mein1 hai1 , bohat1 engaging2.
# 	So2 , now2 I2 guess2 we2 just2 hang2 out2 until2 they2 let2 us2 proceed2 ! Let2 it2 good2 ! 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 To1 , I2 guess2 ham1 bas1 hang2 out1 karte1 hai1 jab1 tak1 wo2 proceed2 nahi1 karne1 dete1 ! jane1 do1 accha1.
# 	Crazy2 stuff2 	 	 <unk> , hai1 	 	 eah1 bahuth1 hi1 manoranjak2 tha1.
# 	What2 do2 you2 think2 about2 it2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 	 	 iske1 baare1 me1 tumhari1 kya1 soch1 hai1 ?.
# 	in2 the2 U2 . S2 . south2 	 	 muje1 , <unk> <unk> <unk> hai1 	 	 US2 South2 me2.
# 	Did1 you2 like2 it2 ? 	 	 <unk> , hai1 hai1 	 	 kya1 aapako1 yah1 pasand1 aaya1 ?.
# 	I2 liked2 him2 as2 Jordan2 Belfort2 . 	 	 muje1 , <unk> <unk> hai1 hai1 	 	 MUJE1 JORDAN1 BELFORT1 PASAND1 HEIN1.
# 	Yes1 I1 do1 	 	 <unk> , hai1 	 	 Yes1 I1 do1.
# 	I2 also2 really2 didn't2 think2 Mia's2 character2 lacked2 depth2 . I2 think2 she2 was2 a2 rather2 round2 character2 , especially2 with2 the2 large2 amount2 of2 independence2 she2 possessed2 . It2 took2 a2 lot2 of2 courage2 for2 her2 to2 move2 back2 to2 Nevada2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mujuhe1 bhi1 aisa1 nahi1 lagta1 ki1 Mia1 ka2 character2 depth2 main2 lack1 karta1 hai1 . Mujhe1 lagta1 hai1 balki1 wo1 round2 character2 thi2 , especially2 usne2 large2 amount2 of2 independence2 ke1 sath1 usne1 possessed2 kiya1 . Use1 bahut1 zada2 courage2 lagi1 hogi1 wapas1 Neveda1 ke1 main1 wapas1 jane1 ke1 liye1.
# 	Dramas2 tend2 to2 kind2 of2 bore2 me2 usually2 , with2 many2 note-worthy2 exceptions2 . I2 like2 Comedies2 mostly2 or2 fantasy2 , Sci-fi2 . I2 will2 check2 it2 out2 though2 , all2 in2 all2 i1 just1 love1 movies1 ! 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 voh1 drama1 toh1 bore1 lagne1 laga1 usme1 jyada1 note2 worthy2 exceptions2 tha1 . muje1 comedies2 aur2 fantasy2 pasand1 aaya1 especially2 sci-fi2 . mein2 check1 kar1 lunga1 , overall2 muje1 movies2 pasand1 hein1.
# 	Loki2 using2 Clint2 Barton2 to2 help2 him2 with2 the2 Tesseract2 was2 awesome2 too1 . I2 like2 him2 even2 though2 he's2 a2 bad2 guy2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Loki1 ka1 Clint2 Barton2 ko1 use1 karna1 Tesseract2 ki1 liye1 help2 k1 liye1 bhi1 awesome1 tha1 . Mujhe1 wo1 pasand1 hai1 even2 though2 wo2 bad2 guy2 hai1.
# 	sorry1 i1 didn't2 watch2 the2 whole2 film2 	 	 muje1 , <unk> <unk> <unk> hai1 hai1 	 	 MAAF1 KAREIN1 , MAIN1 NE1 WAH1 FILM1 POORI1 NAHIN1 DEKHI1.
# 	Yeah1 , maybe2 it's2 OK2 for2 kids2 . They2 like2 the2 predictable2 storylines2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 HAAN1 , MAYBE1 YEH1 KIDS1 KE1 LIYE1 THO1 OK1 HEIN1 .. PREDICTABLE1 STORYLINE1 HEIN1.
# 	Good2 ratings2 	 	 <unk> , hai1 	 	 ache2 ratings2 hein1.
# 	she2 reminds2 of2 my2 friend2 of2 the2 same2 name2 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 <unk> . 	 	 vah1 usee1 naam1 ke1 mere1 friend1 kee1 remind1 karatee1 hai1.
# 	I2 actually2 cried2 when2 I2 first2 watch2 it2 . It2 is2 awesome2 . Got1 52 percent2 in2 rotten2 tomatoes2 but2 I2 will2 give2 it2 a2 100 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mein1 tho1 ro1 rahi1 thi1 jab1 mein1 pehele1 baar1 is1 movie1 ko1 dekha1 ,. yeh1 tho1 awesome1 hein1 ,. mein1 52% rotten2 tomatoes2 ko1 devungi1 lekin1 mein1 100 de1 diya1.
# 	I2 guess2 not2 WWE2 , but2 boxing2 , less2 humans2 , just2 robots2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 wwe1 ka1 tho1 nahi1 hein1 , lekin1 boxing2 , less2 humans2 aur2 robots2 ke2 tho1 jarur1 hoga1.
# 	What2 kind2 of2 weapons2 is2 Stark2 Industries2 selling2 to2 the2 air2 force2 ? 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Stark2 Industries2 air2 force2 ko1 kaise2 weapons2 bech2 rahi1 hai1 ?.
# 	Yes1 , it1 is2 a2 musical2 romatic2 comedy2 ! It2 has2 the2 best2 off2 all2 the2 things2 that2 make2 you2 feel2 good2 ! Romance2 , and2 comedy2 . 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Haan1 . yeh1 comedy2 . musical2 romantic1 Sabse1 acchi1 baat1 yeh1 hai1 ki1 , iame1 ramance1 aur1 comedy1 aapko1 accha1 feel1 karata1 hai1 ..
# 	Ah1 i1 see1 that2 would2 make2 sense2 . 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 	 	 ah1 , ab1 kuch1 sense1 huva1.
# 	Yes2 , the2 whole2 series2 . Did2 you1 know2 Tom2 Selleck2 was2 supposed2 to2 be2 indiana2 jones2 ? 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 haan1 , pooree1 shrrnkhala1 . kya1 aap1 jaanate1 hain1 ki1 tom1 selek2 ko1 indiyaana1 jon1 maana1 jaata1 tha1 ?.
# 	LOL2 	 	 <unk> 	 	 LOL2.
# 	It's2 better2 than2 Man2 of2 Steel2 , the2 superman2 movie2 	 	 muje1 , hai1 <unk> <unk> <unk> hai1 <unk> . 	 	 ye1 superman1 ki1 movie2 Man2 of2 steel2 se2 better1 hai1.
# 	Maleficent2 raises2 a2 child2 who2 she2 dislikes2 , but2 grows2 very2 close2 to2 her2 as2 she2 raises2 her2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Maleficent2 ek1 aise1 bache1 ko1 palti1 hai1 jisse1 wo1 pasand1 nhi1 krti1 , but2 uske1 bahut1 nazdeek1 ho1 jati1 hai1 kyunki1 weh1 use1 palti1 hai1 ..
# 	Do1 you2 feel2 the2 movie2 had2 a2 fitting2 ending2 or2 was2 it2 a2 cliffhanger2 ? 	 	 muje1 , hai1 <unk> ki1 <unk> hai1 <unk> <unk> <unk> <unk> 	 	 Tumhe1 kya1 lagta1 hai1 movie1 ki1 fitting2 ending2 thi1 ya2 cliffhanger2 thi2 ..
# 	I2 liked2 when2 Mike2 and2 Sully2 didn't2 finish2 the2 program2 and2 worked2 their2 way2 up2 the2 ranks2 anyways2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 muje1 acha1 lagga1 jab1 mike1 aur1 ully1 ne1 program1 khatam1 nahi1 kiya1 aur1 phir1 bhi1 mehnat1 se1 tarraki1 ki1.
# 	I2 just2 got2 another2 update2 ... 	 	 muje1 , <unk> <unk> <unk> hai1 	 	 haan1 muje1 dusra1 update1 mila1 ...
# 	yeah1 , im2 sure2 it'll2 be2 a2 great2 one2 	 	 muje1 , <unk> <unk> <unk> <unk> hai1 <unk> . 	 	 Haan1 mujhe1 yakeen1 hai1 ki1 yah1 bahut1 achchaa1 hoga1 ..
# 	I2 was2 mistaken2 . Harry2 Styles2 is2 in2 this2 movie2 . 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Mujhe1 galat1 samajha1 gaya1 tha1 ... iss1 movie2 mein1 Harry2 styles2 hain1 ..
# 	Special2 guest2 appearance2 by2 Ken2 Watanabe2 as1 Ras1 Al2 Ghul1 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Ken2 Watanabe2 ne1 Ras1 Al2 Ghul1 ke1 kirdar1 me1 special2 guest2 appearance2 ki2 hai1 ..
# 	97% rating2 	 	 <unk> , hai1 	 	 97% reting2.
# 	I2 don't2 want2 to2 get2 bored2 . Do1 you1 know1 how2 long2 the2 movie2 is2 ? 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Mujhe1 bore1 nahi1 hona1 . tujhe1 pataa1 hai1 kitni1 lambi1 chalti1 hai1 movie1 ?.
# 	Do1 you2 like2 biopics2 ? If2 you2 do1 this2 movie2 might2 interest2 you2 . 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 aap1 ko1 biopics2 pasand2 hein1 kya1 ? agar1 aapko1 is1 movie1 dekhenge1 toh1 aapko1 interest1 hoga1.
# 	Is1 it2 worth2 watching2 on2 streaming2 ? 	 	 muje1 , hai1 <unk> hai1 hai1 	 	 Stream1 karke1 dekhna1 worth2 hai1 kya1 ?.
# 	I2 thought2 it2 was2 a2 great2 story2 . OVerall1 very2 solid2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Mujhe1 lagta1 tha1 ki1 ye1 ek1 mahan1 kahani1 hai1 . Kul1 milaakar1 bahut1 solid2.
# 	Hi1 , do1 you2 think2 this2 movie2 deserved2 a2 92% Rotten2 Tomatoes2 score2 ? That2 seems2 awfully2 high2 . 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 HI1 , KYA1 ROTTEN1 TOMATOES1 92% DIYA1 JO1 DESERVED1 HEI1 ? VOH1 THO1 AWFULLY1 HIGH1 HEI1 YAR1.
# 	i2 remember2 liking2 it2 , that2 it2 felt2 like2 a2 real2 love2 affair2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Mujhe1 to1 yaad1 aati1 hai1 k1 maine1 pasand1 kiya1 tha1 , aisa1 laga1 k1 real2 love2 affair2 hai1 ..
# 	Yes1 , but2 what2 do2 you2 think2 about2 it2 ? Is1 it2 one2 of2 your2 favorites2 ? 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 acha1 , tho1 aapka1 kya1 khayal1 hein1 ? aapka1 kya1 favorites2 ?.
# 	end2 ? 	 	 <unk> <unk> 	 	 end2 ?.
# 	Got1 good2 reviews2 on2 rotten2 tomatoes2 but2 a2 poor2 score2 on2 Metacritic2 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Rotten2 Tomatoes2 pe2 to1 acche2 review2 hai2 but2 Metacritic2 pe1 bekaar1 score1 hai1.
# 	Yeah1 , that2 was2 classic2 . One2 of2 the2 funniest2 moments2 of2 the2 movie2 . I2 also2 liked2 when2 Iron2 Man2 fell2 back2 through2 the2 wormhole2 . It2 had2 everyone2 on2 edge2 I2 think2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 haan1 , yah1 classic2 tha2 . Movie1 ke1 sabase2 funniest2 moments2 mein1 se1 ek1 . Mujhe1 wo1 bhee1 pasand1 aaya1 jab1 Iron2 Man2 wormhole2 ke1 maadhyam1 se1 vaapas1 gir1 gaya1 . Mujhe1 lagata1 hai1 ki1 yah1 har1 kisee1 ko1 yeh1 edge1 pe1 le1 aaya1 tha1 ..
# 	Did1 your2 description2 just2 go2 away2 ? Mine2 did2 . 	 	 mujhe1 , hai1 <unk> hai1 hai1 	 	 Kya1 tumhara1 description2 chale2 gaya1 ? Mera1 gaya1 ..
# 	Yeah2 , its2 not2 really2 about2 making2 a2 compelling2 story2 but2 I2 guess2 the2 movie2 just2 wants1 you2 to2 have2 fun1 . 	 	 muje1 , hai1 <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Haan1 , ye1 ek1 compelling2 story2 k2 bare1 me1 nahi1 hai1 I1 guess2 movie2 chahti1 hai1 tumhe1 bas1 maja1 aaye1.
# 	what2 is2 it2 about2 	 	 <unk> , hai1 hai1 	 	 kis1 baare1 mein1 ka1 hein1.
# 	I2 haven't2 seen2 Bruce2 Almighty2 for2 some2 reason2 , but2 I2 do2 love2 Jim2 Carrey2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 mein1 bruce2 almighty2 ko1 nahi1 dekha1 kuch1 reason1 ke1 liye1 , lekin1 muej1 jim1 carrey1 pasand1 hein1.
# 	Oh1 good2 question2 ! I2 think2 I2 like2 Mike2 more2 . He's2 weirdly2 optimistic2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 acha1 sawal1 hai1 , mujhe1 mike1 jyada1 acha1 lagta1 hai1 . wo1 alag1 hi2 optimistic2 hai2 ..
# 	Or1 is2 it2 already2 on2 DVD2 ? 	 	 mujhe1 , hai1 hai1 hai1 	 	 Kya1 ye1 DVD2 mei2 already2 hai1 ?.
# 	It2 was2 really2 great2 . We2 camped2 for2 four2 nights2 I2 think2 . It2 rained2 like2 crazy2 the2 first2 day2 , but2 it2 was2 still2 fun2 . 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 Bahut1 maza1 aaya1 tha1 . Humlog1 four2 nights2 camp2 kiye1 the1 . First2 day1 bhayanak1 baarish1 hui1 thi1 , but1 fir1 bhi1 fun1 tha1 ..
# 	Very2 unique2 story2 line2 they2 have2 here2 . Scene2 No2 . 1 really2 sets2 the2 stage2 andbuilds2 interest2 	 	 muje1 , <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> 	 	 bahut1 unique2 story2 line1 hai1 unki1 yaha1 par1 . Scene2 no2 . 1 to2 really2 stage2 set2 kar1 deta1 hai1 aur1 interest2 badha1 deta1 hai1.
# 	how1 are1 u1 ? 	 	 <unk> , hai1 	 	 aap1 kaise1 ho1.
# Processed 1613 lines.

# %%
# import csv

# translated_sentences = open('Paper2.csv','w')
# csvwriter = csv.writer(translated_sentences)
# csvwriter.writerow(['Input','Predicted','Actual'])  

import nltk

bleu_i = []
bleu_o = []

for i, (eng_sentence, hin_sentence) in enumerate(zip(test_data_sent["english"], test_data_sent["hindi"])):

  hindi_predicted = translate(eng_sentence)
  hindi_predicted = " ".join(list(filter(lambda x: x != '<eos>', hindi_predicted))[1:]).strip()
  # csvwriter.writerow([eng_sentence.strip(), hindi_predicted.strip(), hin_sentence.strip()])

  bleu_i.append(hin_sentence.strip())
  bleu_o.append(hindi_predicted.strip())

  # print(eng_sentence.strip())
  # print(hindi_predicted)
  # print()
  # print()

# translated_sentences.close()

BLEU_scores = []

for i in range(len(bleu_i)):
  BLEU_scores.append(nltk.translate.bleu_score.sentence_bleu(bleu_i[i], bleu_o[i], smoothing_function=nltk.translate.bleu_score.SmoothingFunction().method7))
  
print("Average BLEU Score:", np.mean(BLEU_scores))
# Out:
# Average BLEU Score: 0.05751675427023374
